# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.ticker as ticker
from google.cloud import bigquery
import os
from google.cloud import bigquery


# pd.set_option('display.max_columns', None)

os.chdir('/home/jupyter')
# !pwd
# # %cd 
# !pwd
# (base) jupyter@starfire-1:~$ pip install jupyter-console
# (base) jupyter@starfire-1:~$ !jupyter console --existing
# %connect_info
# Out:
# /home/jupyter
# {
#   "shell_port": 60541,
#   "iopub_port": 47859,
#   "stdin_port": 39871,
#   "control_port": 55787,
#   "hb_port": 39843,
#   "ip": "127.0.0.1",
#   "key": "fa8bb050-814a01b561504de227b53b02",
#   "transport": "tcp",
#   "signature_scheme": "hmac-sha256",
#   "kernel_name": "conda-root-py",
#   "jupyter_session": "/home/jupyter/starfire_legacy/refinitiv_mna_deals.ipynb"
# }
#
# Paste the above JSON into a file, and connect with:
#     $> jupyter <app> --existing <file>
# or, if you are local, you can connect with just:
#     $> jupyter <app> --existing kernel-240b0437-5834-4cd9-9d42-17fedda1de8e.json
# or even just:
#     $> jupyter <app> --existing
# if this is the most recent Jupyter kernel you have started.

# %%
# RDP_LOGIN = '<RDP Machine ID>'
# RDP_PASSWORD = '<RDP Password>'
# APP_KEY = '<APP Key>'

import refinitiv.dataplatform as rdp

# %run ./starfire_legacy/credentials.ipynb

session = rdp.open_platform_session(
    APP_KEY,
    rdp.GrantPassword(
        username = RDP_LOGIN,
        password = RDP_PASSWORD
    )
)

# https://developers.lseg.com/en/article-catalog/article/getting-start-with-refinitiv-data-platform

# %%
rdp.get_data(
    universe=["TRI.N", "IBM.N"],
    fields=["TR.Revenue", "TR.GrossProfit"]
)
# Out:
#   instrument   TR.Revenue TR.GrossProfit
# 0      TRI.N   6794000000     6490000000
# 1      IBM.N  61860000000    34300000000

# %%
rdp.get_data(["AAPL.O","MSFT.O"],fields=["TR.F.MktCap"])
# Out:
#   instrument      TR.F.MktCap
# 0     AAPL.O    2676736860720
# 1     MSFT.O  3321869074628.3

# %%
rdp.convert_symbols(
    ['US5949181045', 'US02079K1079', 'US4592001014'], 
    from_symbol_type='ISIN') #TICKER
# rdp.convert_symbols(
#     ['601318'], 
#     from_symbol_type='TICKER')
# Out:
#                  IssueISIN                                      DocumentTitle  \
# US5949181045  US5949181045  Microsoft Corp, Ordinary Share, NASDAQ Global ...
# US02079K1079  US02079K1079  Alphabet Inc, Ordinary Share, Class C, NASDAQ ...
# US4592001014  US4592001014  International Business Machines Corp, Ordinary...
#
#              IssuerOAPermID TickerSymbol      CUSIP     RIC
# US5949181045     4295907168         MSFT  594918104  MSFT.O
# US02079K1079     5030853586         GOOG  02079K107  GOOG.O
# US4592001014     4295904307          IBM  459200101     IBM
# ERROR!!! Failed to request a new token......
#          Token requested error b'{"error":"invalid_grant"   } '
# ERROR!!! request a new refresh token has been failed.
# The server-mode is disabled, so we do not re-authorize with username/password.
# ERROR!!! authentication handler raise an exception.
# ValueError('ERROR!!! request a new refresh token has been failed.\nThe server-mode is disabled, so we do not re-authorize with username/password.')

# %%
# import datetime
# import pytz

# # Initialize the ses
# stock_symbol = 'AAPL.O'  # Example stock symbol for Apple Inc.
# start_date = datetime.datetime(2023, 6, 26, tzinfo=pytz.UTC)  # Example start date with timezone
# end_date = datetime.datetime(2023, 6, 26, tzinfo=pytz.UTC)  # Example end date with timezone
# interval = rdp.Intervals.DAILY
# fields = ['BID', 'ASK', 'OPEN_PRC', 'HIGH_1', 'LOW_1', 'TRDPRC_1', 'NUM_MOVES', 'TRNOVR_UNS']

# response = rdp.get_historical_price_summaries(
#     universe = [stock_symbol],
#     interval = interval,
#     start = start_date,
#     end = end_date,
#     fields = fields
# )


rdp.get_historical_price_summaries(
    universe = 'SPMI.MI', 
    interval = rdp.Intervals.DAILY,
    start = "2020-01-15", 
    end = "2020-01-29",
)
# Out:
#              TRDPRC_1     HIGH_1      LOW_1       ACVOL_UNS   OPEN_PRC  \
# 2020-01-15  11.037308  11.132695  10.949451  3029987.840305  11.074961
# 2020-01-16   11.06492  11.208001  11.004676  2339743.044222  11.077471
# 2020-01-17  11.054879  11.175369  11.047349  2223595.688797  11.115124
# 2020-01-20  11.125165  11.185409  11.069941  1615650.619221  11.097553
# 2020-01-21  11.112614  11.180389  11.024757  1959791.020119  11.180389
# 2020-01-22   10.67082  11.044839  10.603045  7606020.031734  11.027267
# 2020-01-23  10.437373  10.630657  10.354536  3662492.797867  10.593004
# 2020-01-24  10.291781  10.560372  10.281741  2852391.764654  10.482556
# 2020-01-27  10.015661  10.188864   9.972987  4497836.535741  10.188864
# 2020-01-28  10.040762  10.085946   9.822376  4214783.527926  10.040762
# 2020-01-29  10.045783  10.166272   9.985538  4052108.629963  10.116068
#
#                   BID        ASK    TRNOVR_UNS       VWAP  NUM_MOVES  \
# 2020-01-15  11.037308  11.039818  33405653.279  11.025008       4071
# 2020-01-16   11.06492  11.069941  25938964.078  11.086257       3286
# 2020-01-17  11.052369  11.054879  24692870.485  11.104832       3182
# 2020-01-20  11.120144  11.125165    17976270.0   11.12642       2969
# 2020-01-21  11.112614  11.115124  21765551.199  11.106087       2978
# 2020-01-22   10.67082  10.683371  81482584.352  10.712991      12348
# 2020-01-23  10.434862  10.442393  38497640.539  10.511423       6041
# 2020-01-24  10.289271  10.291781  29667866.444  10.400975       4577
# 2020-01-27   10.01315  10.015661   45237496.02  10.057581       7475
# 2020-01-28  10.040762  10.045783   42007579.85   9.966712       7310
# 2020-01-29  10.040762  10.045783  40761914.559  10.059338       5587
#
#             OFF_CLOSE     CLS_AUCVOL     OPN_AUCVOL    OPN_AUC    CLS_AUC  \
# 2020-01-15  11.037308  340083.736837    9482.945233  11.074961  11.037308
# 2020-01-16   11.06492  232562.817981   21753.726575  11.077471   11.06492
# 2020-01-17  11.054879  150166.286076    22605.05635  11.115124  11.054879
# 2020-01-20  11.125165  106425.384518   24815.645456  11.097553  11.125165
# 2020-01-21  11.112614  195015.470008   70223.352713  11.180389  11.112614
# 2020-01-22   10.67082  654175.423527   78100.045418  11.027267   10.67082
# 2020-01-23  10.437373  319856.985942   46451.054323  10.593004  10.437373
# 2020-01-24  10.291781   211257.66292    15911.54073  10.482556  10.291781
# 2020-01-27  10.015661  325603.163141  191119.749901  10.188864  10.015661
# 2020-01-28  10.040762  498793.198872   11223.450514  10.040762  10.040762
# 2020-01-29  10.045783  481394.520074    31877.65899  10.116068  10.045783
#
#            TRD_STATUS INT_AUC INT_AUCVOL NAVALUE
# 2020-01-15       None    None       None    None
# 2020-01-16       None    None       None    None
# 2020-01-17       None    None       None    None
# 2020-01-20       None    None       None    None
# 2020-01-21       None    None       None    None
# 2020-01-22       None    None       None    None
# 2020-01-23       None    None       None    None
# 2020-01-24       None    None       None    None
# 2020-01-27       None    None       None    None
# 2020-01-28       None    None       None    None
# 2020-01-29       None    None       None    None

# %%
print(datetime.timedelta(0))
# Out:
# <module 'datetime' from '/opt/conda/lib/python3.10/datetime.py'>

# %%
mna_screen = f'SCREEN(U(IN(DEALS)/*UNV:DEALSMNA*/),\
                    BETWEEN(TR.MnAAnnDate,20000101,20241231)/*dt:Date*/, \
                    IN(TR.MnAAcquiror, "TRIMBLE NAVIGATION LTD"),\
                    NOT_IN(TR.MnAAcquirorNation, "CN"),\
                    NOT_IN(TR.MnAStatus, "S", "R", "DR", "W", "SW"), \
                    CURN=USD)'


# input ipo screen results as instrument list and pull ipo attributes via fields from Eikon Data API. 
mnas = rdp.get_data(mna_screen,['TR.MnASDCDealNumber',
                               'TR.MnAAnnDate',
                               'TR.MnARankValueIncNetDebt(Curn=USD,Scale=6)',
                               'TR.MnADealValue(Curn=USD,Scale=6)', 'TR.MnADealCurrency',
                               'TR.MnADealType',
                               'TR.MnAType',
                               'TR.MnATarget', 'TR.MnATargetNation', 'TR.MnATargetSDCCusip',
                               'TR.MnAAcquiror', 'TR.MnAAcquirorNation', 'TR.MnAAcquirorSDCCusip',
                               'TR.MnAAcquirorUltParent', 'TR.MnAAcquirorUltParentSDCCusip',
                               'TR.MnAPctHeldAtAnnDate', 'TR.MnAPctOfSharesAcquired', 'TR.MnAPctOfSharesAcqSeeksToOwn',
                               'TR.MnAStatus',
                               'TR.MnAAcquirorPriTickerSym',
                               'MnAAcquirorUltParentPriTickerSym',
                               'TR.MnACompDealId(Concat="|")']) 

print(mnas.shape)
mnas
# Out:
# (97, 22)
#       instrument TR.MNASDCDealNumber TR.MnAAnnDate  TR.MnARankValueIncNetDebt  \
# 0    34391219589          1005549020    2000-05-11                      294.0
# 1    34391224495          1051097020    2000-09-21                       15.0
# 2    34391244403          1357768020    2002-06-28                        6.0
# 3    34391254559          1498950020    2004-02-17                       <NA>
# 4    34391262279          1626471020    2004-12-21                       <NA>
# ..           ...                 ...           ...                        ...
# 92  154082967973          2818735040    2015-11-10                       <NA>
# 93  154082968769          2819290020    2015-11-11                       <NA>
# 94  154083005207          2918733040    2016-02-08                       <NA>
# 95  154083096302          2989728040    2016-08-01                       <NA>
# 96  154083198712          3068198020    2017-02-08                       <NA>
#
#     TR.MnADealValue      TR.MnADealCurrency                 TR.MnADealType  \
# 0             294.0               US Dollar    Disclosed Dollar Value Deal
# 1              15.0               US Dollar    Disclosed Dollar Value Deal
# 2               6.0               US Dollar    Disclosed Dollar Value Deal
# 3              <NA>               US Dollar  Undisclosed Dollar Value Deal
# 4              <NA>               US Dollar  Undisclosed Dollar Value Deal
# ..              ...                     ...                            ...
# 92             <NA>         Canadian Dollar  Undisclosed Dollar Value Deal
# 93             <NA>               US Dollar  Undisclosed Dollar Value Deal
# 94             <NA>  British Pound Sterling  Undisclosed Dollar Value Deal
# 95             <NA>                    Euro  Undisclosed Dollar Value Deal
# 96             <NA>               US Dollar  Undisclosed Dollar Value Deal
#
#            TR.MnAType                 TR.MnATarget TR.MnATargetNation  ...  \
# 0     Disclosed Value        Spectra Precision Inc      United States  ...
# 1     Disclosed Value  Tripod Data System Inc{TDS}      United States  ...
# 2     Disclosed Value      LeveLite Technology Inc      United States  ...
# 3   Undisclosed Value               TracerNet Corp      United States  ...
# 4   Undisclosed Value           Pacific Crest Corp      United States  ...
# ..                ...                          ...                ...  ...
# 92  Undisclosed Value         Agri-Trend Data Corp             Canada  ...
# 93  Undisclosed Value        Telog Instruments Inc      United States  ...
# 94  Undisclosed Value                  Sefaira Ltd     United Kingdom  ...
# 95  Undisclosed Value                AXIO-NET GmbH            Germany  ...
# 96  Undisclosed Value     Beena Vision Systems Inc      United States  ...
#
#    TR.MnAAcquirorNation TR.MnAAcquirorSDCCusip TR.MnAAcquirorUltParent  \
# 0         United States                 896239  Trimble Navigation Ltd
# 1         United States                 896239  Trimble Navigation Ltd
# 2         United States                 896239  Trimble Navigation Ltd
# 3         United States                 896239  Trimble Navigation Ltd
# 4         United States                 896239  Trimble Navigation Ltd
# ..                  ...                    ...                     ...
# 92        United States                 896239  Trimble Navigation Ltd
# 93        United States                 896239  Trimble Navigation Ltd
# 94        United States                 896239  Trimble Navigation Ltd
# 95        United States                 896239  Trimble Navigation Ltd
# 96        United States                 3H8772  Trimble Navigation LTD
#
#    TR.MnAAcquirorUltParentSDCCusip TR.MnAPctHeldAtAnnDate  \
# 0                           896239                   <NA>
# 1                           896239                   <NA>
# 2                           896239                   <NA>
# 3                           896239                   <NA>
# 4                           896239                   <NA>
# ..                             ...                    ...
# 92                          896239                   <NA>
# 93                          896239                   <NA>
# 94                          896239                   <NA>
# 95                          896239                   <NA>
# 96                          3H8772                   <NA>
#
#    TR.MnAPctOfSharesAcquired  TR.MnAPctOfSharesAcqSeeksToOwn  TR.MnAStatus  \
# 0                      100.0                             100     Completed
# 1                        0.0                             100       Pending
# 2                      100.0                             100     Completed
# 3                      100.0                             100     Completed
# 4                        0.0                             100       Pending
# ..                       ...                             ...           ...
# 92                       0.0                             100       Pending
# 93                     100.0                             100     Completed
# 94                     100.0                             100     Completed
# 95                     100.0                             100     Completed
# 96                     100.0                             100     Completed
#
#     TR.MnAAcquirorPriTickerSym TR.MnACompDealId
# 0                         TRMB
# 1                         TRMB
# 2                         TRMB
# 3                         TRMB
# 4                         TRMB
# ..                         ...              ...
# 92                        TRMB
# 93                        TRMB
# 94                        TRMB
# 95                        TRMB
# 96
#
# [97 rows x 22 columns]
# ERROR!!! Failed to request a new token......
#          Token requested error b'{"error":"invalid_grant"   } '
# ERROR!!! request a new refresh token has been failed.
# The server-mode is disabled, so we do not re-authorize with username/password.
# ERROR!!! authentication handler raise an exception.
# ValueError('ERROR!!! request a new refresh token has been failed.\nThe server-mode is disabled, so we do not re-authorize with username/password.')

# %%
mna_screen = f'SCREEN(U(IN(DEALS)/*UNV:DEALSMNA*/),\
                    BETWEEN(TR.MnAAnnDate,20180101,20180105)/*dt:Date*/, \
                    CURN=USD)'


# input ipo screen results as instrument list and pull ipo attributes via fields from Eikon Data API. 
mnas = rdp.get_data(mna_screen,['TR.MNASDCDealNumber',
                                'TR.MnAAnnDate',
                                'TR.MnARankValueIncNetDebt(Curn=USD,Scale=6)',
                                'TR.MnATarget',
                                'TR.MnATargetPermId',
                                'TR.MnATargetPriTickerSym',
                                'TR.MnATargetNation',
                                'TR.MnATargetMacroInd',
                                'TR.MnATargetMidInd',
                                'TR.MnAAcquiror',
                                'TR.MnAAcquirorPermId',
                                'TR.MnAAcquirorMacroInd',
                                'TR.MnAAcquirorMidInd',
                                'TR.MnAAcquirorNation',
                                'TR.MNASDCDealNumber',
                                'TR.MNADealId','TR.MnASynopsis',
                                'TR.MnAAcquirorPermId',
                                'TR.MnAAcquirorPriHiTech',
                                'TR.MnAAcquirorPriTickerSym',
                                'TR.MnAAcquirorExchTicker(Concat="|")',
                                'TR.MnAAcquirorUltParentPermID',
                                'TR.MnAHiTechGroup(Concat="|")',
                                'TR.MnaAcquirorDate1DayPriorToAnn',
                                'TR.MnaAcquirorStockPrice1DayPriorToAnnInAcqCurr',
                                'TR.MnAAcquirorStockPriceOnAnn(Curn=USD)',
                                'TR.MnAAcquirorStockPrice1DayPostAnn(Curn=USD)',
                                'TR.MnASnP5001DayPreAnn',
                                'TR.MnASnP500AtAnnouncement',
                                'TR.MnASnP5001DayPostAnn',
                                'TR.MnATargetSDCCusip',
                                'TR.MnAAcquirorSDCCusip',
                                'TR.MnAAcquirorUltParentSDCCusip',
                                'TR.MnAValueOfCash(Curn=USD, Scale=6)',
                                'TR.MnAValueOfEarnout(Curn=USD, Scale=6)',
                                'TR.MnADealValue(Curn=USD, Scale=6)',
                                'TR.MnAAcquirorHiTech(Concat="|")',
                                'TR.MnAAcquirorUltParentHiTech(Concat="|")',
                                'TR.MnATargetPriHiTech',
                                'TR.MnAAcquirorMajorInd',
                                'TR.MnAAcquirorMajorIndGrp',
                                'TR.MnAAcquirorPriVEIC',
                                'TR.MnAMasterDealType',
                                'TR.MnADealType',
                                'TR.MnAType(Concat="|")',
                                'TR.MnAAcquirorVeic(Concat="|")',
                                'TR.MnAPurposeDescription',
                                'TR.MnAIsCrossBorder',
                                'TR.MnAAcquirorIsVentureFirm',
                                'TR.MnATargetPriVEIC',
                                'TR.MnATargetVeic(Concat="|")',
                                'TR.MnAAcquirorBusDesc',
                                'TR.MnATargetBusDesc',
                                'TR.MnATargetPermId',
                                'TR.MnATargetExchTicker(Concat="|")',
                                'TR.MnATargetUltParentSDCCusip',
                                'TR.MnATargetUltParentPriTickerSym',
                                'TR.MnATargetUltParentPermID',
                                'TR.MnAAcquirorUltParentPriTickerSym',
                                'TR.MnAAcquirorUltParentExchTicker(Concat="|")',
                                'TR.MnATargetUltParentExchTicker(Concat="|")',
                                'TR.MnATargetMajorInd',
                                'TR.MnATargetMajorIndGrp',
                                'TR.MnATargetHiTech(Concat="|")',
                                'TR.MnAAcquirorUltParentPriHiTech',
                                'TR.MnAAcquirorHiTechGroup(Concat="|")',
                                'TR.MnATargetHiTechGroup(Concat="|")',
                                'TR.MnAWithdrawnDate',
                                'TR.MnADateUnconditional',
                                'TR.MnAOrigAnnDate',
                                'TR.MnAPercentCash',
                                'TR.MnADealCurrency',
                                'TR.MnAEarnoutDesc']) 

print(mnas.shape)
print(mnas.columns)
mnas
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 83
#      80 # input ipo screen results as instrument list and pull ipo attributes via fields from Eikon Data API.
#      81 mnas = rdp.get_data(mna_screen, list_variables)
# ---> 83 print(mnas.shape)
#      84 print(mnas.columns)
#      85 mnas
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
print(mnas['TR.MnAType'].value_counts())
print(mnas['TR.MnADealType'].value_counts())
mnas[mnas['TR.MnATarget'].str.contains('Yamei')]
# Out:
# TR.MnAType
# Undisclosed Value                     78
# Disclosed Value                       12
# Repurchases                            3
# Tender Offers                          2
# Acquisitions of Remaining Interest     1
# Privatizations                         1
# Name: count, dtype: Int64
# TR.MnADealType
# Undisclosed Dollar Value Deal    78
# Disclosed Dollar Value Deal      12
# Repurchases Deal                  3
# Name: count, dtype: Int64
#      instrument TR.MNASDCDealNumber TR.MnAAnnDate  TR.MnARankValueIncNetDebt  \
# 54  34392053993          2319296040    2011-06-14                       <NA>
#
#     TR.MnADealValue TR.MnADealCurrency                 TR.MnADealType  \
# 54             <NA>       Chinese Yuan  Undisclosed Dollar Value Deal
#
#            TR.MnAType                                   TR.MnATarget  \
# 54  Undisclosed Value  Changchun Yamei Electronics Technology Co Ltd
#
#    TR.MnATargetNation  ...          TR.MnAAcquiror TR.MnAAcquirorNation  \
# 54   China (Mainland)  ...  Trimble Navigation Ltd        United States
#
#    TR.MnAAcquirorSDCCusip TR.MnAAcquirorUltParent  \
# 54                 896239  Trimble Navigation Ltd
#
#    TR.MnAAcquirorUltParentSDCCusip TR.MnAPctHeldAtAnnDate  \
# 54                          896239                   <NA>
#
#     TR.MnAPctOfSharesAcquired  TR.MnAPctOfSharesAcqSeeksToOwn  TR.MnAStatus  \
# 54                      100.0                             100     Completed
#
#    TR.MnACompDealId
# 54
#
# [1 rows x 21 columns]
# ERROR!!! Failed to request a new token......
#          Token requested error b'{"error":"invalid_grant"   } '
# ERROR!!! request a new refresh token has been failed.
# The server-mode is disabled, so we do not re-authorize with username/password.
# ERROR!!! authentication handler raise an exception.
# ValueError('ERROR!!! request a new refresh token has been failed.\nThe server-mode is disabled, so we do not re-authorize with username/password.')

# %%
# Initialize a BigQuery client
client = bigquery.Client()

# Define your project, dataset, and table
project_id = "starfire-410116"
dataset_id = "derived"
table_id = "refinitiv_deals_2"


# Construct a reference to the target table
table_ref = client.dataset(dataset_id).table(table_id)

# Configure the load job to append data to the existing table
job_config = bigquery.LoadJobConfig(
    write_disposition=bigquery.WriteDisposition.WRITE_APPEND
)


from datetime import datetime, timedelta

# Initial start date
start_date = datetime.strptime('19900101', '%Y%m%d')

# Define the interval (15 days)
interval = timedelta(days=10)

# Initialize an empty list to store the date ranges
date_ranges = []

# Loop to create date intervals
for _ in range(10000):  # Adjust the range to get the desired number of intervals
    end_date = start_date + interval
    date_ranges.append((start_date.strftime('%Y%m%d'), end_date.strftime('%Y%m%d')))
    start_date = end_date + timedelta(days=1)

# Print the date ranges
for start, end in date_ranges:
    success = False
    while not success:
        try:
            print(f"Start Date: {start}, End Date: {end}")

            print("Downloading data from refinitiv...")

            mna_screen = f'SCREEN(U(IN(DEALS)/*UNV:DEALSMNA*/),\
                        BETWEEN(TR.MnAAnnDate,{start},{end})/*dt:Date*/, \
                        NOT_IN(TR.MnAAcquirorNation, "CN"),\
                        NOT_IN(TR.MnAStatus, "S", "R", "DR", "W", "SW"), \
                        CURN=USD)'


            # input ipo screen results as instrument list and pull ipo attributes via fields from Eikon Data API. 
            mnas = rdp.get_data(mna_screen, ['TR.MnASDCDealNumber',
                                           'TR.MnAAnnDate',
                                           'TR.MnARankValueIncNetDebt(Curn=USD,Scale=6)',
                                           'TR.MnADealValue(Curn=USD,Scale=6)', 'TR.MnADealCurrency',
                                           'TR.MnADealType',
                                           'TR.MnATarget', 'TR.MnATargetNation', 'TR.MnATargetSDCCusip',
                                           'TR.MnAAcquiror', 'TR.MnAAcquirorNation', 'TR.MnAAcquirorSDCCusip',
                                           'TR.MnAAcquirorUltParent', 'TR.MnAAcquirorUltParentSDCCusip',
                                           'TR.MnAPctHeldAtAnnDate', 'TR.MnAPctOfSharesAcquired', 'TR.MnAPctOfSharesAcqSeeksToOwn',
                                           'TR.MnAStatus',
                                           'TR.MnACompDealId(Concat="|")']) 
            print(mnas.shape)

            print("Uploading data to BQ...")
            mnas.columns = [col[3:].lower() for col in mnas.columns]

            # Load the DataFrame into BigQuery
            load_job = client.load_table_from_dataframe(mnas, table_ref, job_config=job_config)

            # Wait for the load job to complete
            load_job.result()

            print("Data appended successfully.")

            success = True 
            
        except Exception as e:
            print(f"An error occurred: {e}. Retrying for the range {start} to {end}...")
# Out:
# Start Date: 19981031, End Date: 19981110
# Downloading data from refinitiv...
# (410, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 19981111, End Date: 19981121
# Downloading data from refinitiv...
# (482, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 19981122, End Date: 19981202
# Downloading data from refinitiv...
# (500, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 19981203, End Date: 19981213
# Downloading data from refinitiv...
# ERROR!!! An error occurred while requesting URL('https://api.refinitiv.com/data/datagrid/beta1/').
#      ReadTimeout('')
# An error occurred: . Retrying for the range 19981203 to 19981213...
# Start Date: 19981203, End Date: 19981213
# Downloading data from refinitiv...
# ERROR!!! An error occurred while requesting URL('https://api.refinitiv.com/data/datagrid/beta1/').
#      ReadTimeout('')
# An error occurred: . Retrying for the range 19981203 to 19981213...
# Start Date: 19981203, End Date: 19981213
# Downloading data from refinitiv...
# (423, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 19981214, End Date: 19981224
# Downloading data from refinitiv...
# (658, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 19981225, End Date: 19990104
# Downloading data from refinitiv...
# (353, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 19990105, End Date: 19990115
# Downloading data from refinitiv...
# (601, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 19990116, End Date: 19990126
# Downloading data from refinitiv...
# (417, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 19990127, End Date: 19990206
# Downloading data from refinitiv...
# (594, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 19990207, End Date: 19990217
# Downloading data from refinitiv...
# (473, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 19990218, End Date: 19990228
# Downloading data from refinitiv...
# (465, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 19990301, End Date: 19990311
# Downloading data from refinitiv...
# (651, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 19990312, End Date: 19990322
# Downloading data from refinitiv...
# (468, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 19990323, End Date: 19990402
# Downloading data from refinitiv...
# ERROR!!! An error occurred while requesting URL('https://api.refinitiv.com/data/datagrid/beta1/').
#      ReadTimeout('')
# An error occurred: . Retrying for the range 19990323 to 19990402...
# Start Date: 19990323, End Date: 19990402
# Downloading data from refinitiv...
# ERROR!!! An error occurred while requesting URL('https://api.refinitiv.com/data/datagrid/beta1/').
#      ReadTimeout('')
# An error occurred: . Retrying for the range 19990323 to 19990402...
# Start Date: 19990323, End Date: 19990402
# Downloading data from refinitiv...
# ERROR!!! An error occurred while requesting URL('https://api.refinitiv.com/data/datagrid/beta1/').
#      ReadTimeout('')
# An error occurred: . Retrying for the range 19990323 to 19990402...
# Start Date: 19990323, End Date: 19990402
# Downloading data from refinitiv...
# (681, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 19990403, End Date: 19990413
# Downloading data from refinitiv...
# (445, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 19990414, End Date: 19990424
# Downloading data from refinitiv...
# (563, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 19990425, End Date: 19990505
# Downloading data from refinitiv...
# (602, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 19990506, End Date: 19990516
# Downloading data from refinitiv...
# (478, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 19990517, End Date: 19990527
# Downloading data from refinitiv...
# (627, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 19990528, End Date: 19990607
# Downloading data from refinitiv...
# (531, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 19990608, End Date: 19990618
# Downloading data from refinitiv...
# ERROR!!! An error occurred while requesting URL('https://api.refinitiv.com/data/datagrid/beta1/').
#      ReadTimeout('')
# An error occurred: . Retrying for the range 19990608 to 19990618...
# Start Date: 19990608, End Date: 19990618
# Downloading data from refinitiv...
# ERROR!!! An error occurred while requesting URL('https://api.refinitiv.com/data/datagrid/beta1/').
#      ReadTimeout('')
# An error occurred: . Retrying for the range 19990608 to 19990618...
# Start Date: 19990608, End Date: 19990618
# Downloading data from refinitiv...
# (624, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 19990619, End Date: 19990629
# Downloading data from refinitiv...
# (573, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 19990630, End Date: 19990710
# Downloading data from refinitiv...
# (659, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 19990711, End Date: 19990721
# Downloading data from refinitiv...
# (574, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 19990722, End Date: 19990801
# Downloading data from refinitiv...
# (520, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 19990802, End Date: 19990812
# Downloading data from refinitiv...
# (544, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 19990813, End Date: 19990823
# Downloading data from refinitiv...
# (430, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 19990824, End Date: 19990903
# Downloading data from refinitiv...
# (609, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 19990904, End Date: 19990914
# Downloading data from refinitiv...
# (486, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 19990915, End Date: 19990925
# Downloading data from refinitiv...
# (572, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 19990926, End Date: 19991006
# Downloading data from refinitiv...
# (670, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 19991007, End Date: 19991017
# Downloading data from refinitiv...
# (424, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 19991018, End Date: 19991028
# Downloading data from refinitiv...
# (595, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 19991029, End Date: 19991108
# Downloading data from refinitiv...
# (498, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 19991109, End Date: 19991119
# Downloading data from refinitiv...
# (653, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 19991120, End Date: 19991130
# Downloading data from refinitiv...
# (516, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 19991201, End Date: 19991211
# Downloading data from refinitiv...
# (623, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 19991212, End Date: 19991222
# Downloading data from refinitiv...
# (788, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 19991223, End Date: 20000102
# Downloading data from refinitiv...
# (446, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20000103, End Date: 20000113
# Downloading data from refinitiv...
# (605, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20000114, End Date: 20000124
# Downloading data from refinitiv...
# (595, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20000125, End Date: 20000204
# Downloading data from refinitiv...
# (769, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20000205, End Date: 20000215
# Downloading data from refinitiv...
# (616, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20000216, End Date: 20000226
# Downloading data from refinitiv...
# (701, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20000227, End Date: 20000308
# Downloading data from refinitiv...
# (866, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20000309, End Date: 20000319
# Downloading data from refinitiv...
# (593, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20000320, End Date: 20000330
# Downloading data from refinitiv...
# ERROR!!! An error occurred while requesting URL('https://api.refinitiv.com/data/datagrid/beta1/').
#      ReadTimeout('')
# An error occurred: . Retrying for the range 20000320 to 20000330...
# Start Date: 20000320, End Date: 20000330
# Downloading data from refinitiv...
# (842, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20000331, End Date: 20000410
# Downloading data from refinitiv...
# (720, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20000411, End Date: 20000421
# Downloading data from refinitiv...
# (673, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20000422, End Date: 20000502
# Downloading data from refinitiv...
# ERROR!!! An error occurred while requesting URL('https://api.refinitiv.com/data/datagrid/beta1/').
#      ReadTimeout('')
# An error occurred: . Retrying for the range 20000422 to 20000502...
# Start Date: 20000422, End Date: 20000502
# Downloading data from refinitiv...
# ERROR!!! An error occurred while requesting URL('https://api.refinitiv.com/data/datagrid/beta1/').
#      ReadTimeout('')
# An error occurred: . Retrying for the range 20000422 to 20000502...
# Start Date: 20000422, End Date: 20000502
# Downloading data from refinitiv...
# (537, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20000503, End Date: 20000513
# Downloading data from refinitiv...
# (682, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20000514, End Date: 20000524
# Downloading data from refinitiv...
# (687, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20000525, End Date: 20000604
# Downloading data from refinitiv...
# (583, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20000605, End Date: 20000615
# Downloading data from refinitiv...
# (705, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20000616, End Date: 20000626
# Downloading data from refinitiv...
# (617, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20000627, End Date: 20000707
# Downloading data from refinitiv...
# (805, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20000708, End Date: 20000718
# Downloading data from refinitiv...
# (571, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20000719, End Date: 20000729
# Downloading data from refinitiv...
# (682, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20000730, End Date: 20000809
# Downloading data from refinitiv...
# (653, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20000810, End Date: 20000820
# Downloading data from refinitiv...
# (478, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20000821, End Date: 20000831
# Downloading data from refinitiv...
# ERROR!!! An error occurred while requesting URL('https://api.refinitiv.com/data/datagrid/beta1/').
#      ReadTimeout('')
# An error occurred: . Retrying for the range 20001209 to 20001219...
# Start Date: 20001209, End Date: 20001219
# Downloading data from refinitiv...
# (612, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20001220, End Date: 20001230
# Downloading data from refinitiv...
# (568, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20001231, End Date: 20010110
# Downloading data from refinitiv...
# (519, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20010111, End Date: 20010121
# Downloading data from refinitiv...
# (518, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20010122, End Date: 20010201
# Downloading data from refinitiv...
# ERROR!!! An error occurred while requesting URL('https://api.refinitiv.com/data/datagrid/beta1/').
#      ReadTimeout('')
# An error occurred: . Retrying for the range 20010122 to 20010201...
# Start Date: 20010122, End Date: 20010201
# Downloading data from refinitiv...
# ERROR!!! An error occurred while requesting URL('https://api.refinitiv.com/data/datagrid/beta1/').
#      ReadTimeout('')
# An error occurred: . Retrying for the range 20010122 to 20010201...
# Start Date: 20010122, End Date: 20010201
# Downloading data from refinitiv...
# (611, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20010202, End Date: 20010212
# Downloading data from refinitiv...
# (466, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20010213, End Date: 20010223
# Downloading data from refinitiv...
# (616, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20010224, End Date: 20010306
# Downloading data from refinitiv...
# ERROR!!! An error occurred while requesting URL('https://api.refinitiv.com/data/datagrid/beta1/').
#      ReadTimeout('')
# An error occurred: . Retrying for the range 20010224 to 20010306...
# Start Date: 20010224, End Date: 20010306
# Downloading data from refinitiv...
# (510, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20010307, End Date: 20010317
# Downloading data from refinitiv...
# (539, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20010318, End Date: 20010328
# Downloading data from refinitiv...
# (538, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20010329, End Date: 20010408
# Downloading data from refinitiv...
# (597, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20010409, End Date: 20010419
# Downloading data from refinitiv...
# (501, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20010420, End Date: 20010430
# Downloading data from refinitiv...
# (475, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20010501, End Date: 20010511
# Downloading data from refinitiv...
# (578, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20010512, End Date: 20010522
# Downloading data from refinitiv...
# (459, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20010523, End Date: 20010602
# Downloading data from refinitiv...
# (562, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20010603, End Date: 20010613
# Downloading data from refinitiv...
# (489, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20010614, End Date: 20010624
# Downloading data from refinitiv...
# (423, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20010625, End Date: 20010705
# Downloading data from refinitiv...
# (683, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20010706, End Date: 20010716
# Downloading data from refinitiv...
# (452, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20010717, End Date: 20010727
# Downloading data from refinitiv...
# (543, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20010728, End Date: 20010807
# Downloading data from refinitiv...
# (473, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20010808, End Date: 20010818
# Downloading data from refinitiv...
# (392, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20010819, End Date: 20010829
# Downloading data from refinitiv...
# (380, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20010830, End Date: 20010909
# Downloading data from refinitiv...
# (394, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20010910, End Date: 20010920
# Downloading data from refinitiv...
# (428, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20010921, End Date: 20011001
# Downloading data from refinitiv...
# (446, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20011002, End Date: 20011012
# Downloading data from refinitiv...
# (434, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20011013, End Date: 20011023
# Downloading data from refinitiv...
# (422, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20011024, End Date: 20011103
# Downloading data from refinitiv...
# (516, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20011104, End Date: 20011114
# Downloading data from refinitiv...
# (451, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20011115, End Date: 20011125
# Downloading data from refinitiv...
# (367, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20011126, End Date: 20011206
# Downloading data from refinitiv...
# (564, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20011207, End Date: 20011217
# Downloading data from refinitiv...
# (411, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20011218, End Date: 20011228
# Downloading data from refinitiv...
# (480, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20011229, End Date: 20020108
# Downloading data from refinitiv...
# (373, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20020109, End Date: 20020119
# Downloading data from refinitiv...
# (436, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20020120, End Date: 20020130
# Downloading data from refinitiv...
# (409, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20020131, End Date: 20020210
# Downloading data from refinitiv...
# (406, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20020211, End Date: 20020221
# Downloading data from refinitiv...
# (426, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20020222, End Date: 20020304
# Downloading data from refinitiv...
# (427, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20020305, End Date: 20020315
# Downloading data from refinitiv...
# (460, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20020316, End Date: 20020326
# Downloading data from refinitiv...
# (411, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20020327, End Date: 20020406
# Downloading data from refinitiv...
# (448, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20020407, End Date: 20020417
# Downloading data from refinitiv...
# (413, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20020418, End Date: 20020428
# Downloading data from refinitiv...
# (409, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20020429, End Date: 20020509
# Downloading data from refinitiv...
# ERROR!!! An error occurred while requesting URL('https://api.refinitiv.com/data/datagrid/beta1/').
#      ReadTimeout('')
# An error occurred: . Retrying for the range 20020429 to 20020509...
# Start Date: 20020429, End Date: 20020509
# Downloading data from refinitiv...
# ERROR!!! An error occurred while requesting URL('https://api.refinitiv.com/data/datagrid/beta1/').
#      ReadTimeout('')
# An error occurred: . Retrying for the range 20020429 to 20020509...
# Start Date: 20020429, End Date: 20020509
# Downloading data from refinitiv...
# (474, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20020510, End Date: 20020520
# Downloading data from refinitiv...
# (412, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20020521, End Date: 20020531
# Downloading data from refinitiv...
# ERROR!!! An error occurred while requesting URL('https://api.refinitiv.com/data/datagrid/beta1/').
#      ReadTimeout('')
# An error occurred: . Retrying for the range 20020521 to 20020531...
# Start Date: 20020521, End Date: 20020531
# Downloading data from refinitiv...
# ERROR!!! An error occurred while requesting URL('https://api.refinitiv.com/data/datagrid/beta1/').
#      ReadTimeout('')
# An error occurred: . Retrying for the range 20020521 to 20020531...
# Start Date: 20020521, End Date: 20020531
# Downloading data from refinitiv...
# ERROR!!! An error occurred while requesting URL('https://api.refinitiv.com/data/datagrid/beta1/').
#      ReadTimeout('')
# An error occurred: . Retrying for the range 20020521 to 20020531...
# Start Date: 20020521, End Date: 20020531
# Downloading data from refinitiv...
# (505, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20020601, End Date: 20020611
# Downloading data from refinitiv...
# ERROR!!! An error occurred while requesting URL('https://api.refinitiv.com/data/datagrid/beta1/').
#      ReadTimeout('')
# An error occurred: . Retrying for the range 20020601 to 20020611...
# Start Date: 20020601, End Date: 20020611
# Downloading data from refinitiv...
# ERROR!!! An error occurred while requesting URL('https://api.refinitiv.com/data/datagrid/beta1/').
#      ReadTimeout('')
# An error occurred: . Retrying for the range 20020601 to 20020611...
# Start Date: 20020601, End Date: 20020611
# Downloading data from refinitiv...
# (378, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20020612, End Date: 20020622
# Downloading data from refinitiv...
# ERROR!!! An error occurred while requesting URL('https://api.refinitiv.com/data/datagrid/beta1/').
#      ReadTimeout('')
# An error occurred: . Retrying for the range 20020612 to 20020622...
# Start Date: 20020612, End Date: 20020622
# Downloading data from refinitiv...
# ERROR!!! An error occurred while requesting URL('https://api.refinitiv.com/data/datagrid/beta1/').
#      ReadTimeout('')
# An error occurred: . Retrying for the range 20020612 to 20020622...
# Start Date: 20020612, End Date: 20020622
# Downloading data from refinitiv...
# (389, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20020623, End Date: 20020703
# Downloading data from refinitiv...
# (496, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20020704, End Date: 20020714
# Downloading data from refinitiv...
# (339, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20020715, End Date: 20020725
# Downloading data from refinitiv...
# (493, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20020726, End Date: 20020805
# Downloading data from refinitiv...
# (447, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20020806, End Date: 20020816
# Downloading data from refinitiv...
# An error occurred: 'NoneType' object has no attribute 'shape'. Retrying for the range 20020806 to 20020816...
# Start Date: 20020806, End Date: 20020816
# Downloading data from refinitiv...
# (411, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20020817, End Date: 20020827
# Downloading data from refinitiv...
# (303, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20020828, End Date: 20020907
# Downloading data from refinitiv...
# (413, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20020908, End Date: 20020918
# Downloading data from refinitiv...
# (426, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20020919, End Date: 20020929
# Downloading data from refinitiv...
# (383, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20020930, End Date: 20021010
# Downloading data from refinitiv...
# (513, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20021011, End Date: 20021021
# Downloading data from refinitiv...
# (371, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20021022, End Date: 20021101
# Downloading data from refinitiv...
# ERROR!!! An error occurred while requesting URL('https://api.refinitiv.com/data/datagrid/beta1/').
#      ReadTimeout('')
# An error occurred: . Retrying for the range 20021022 to 20021101...
# Start Date: 20021022, End Date: 20021101
# Downloading data from refinitiv...
# (508, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20021102, End Date: 20021112
# Downloading data from refinitiv...
# (363, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20021113, End Date: 20021123
# Downloading data from refinitiv...
# (417, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20021124, End Date: 20021204
# Downloading data from refinitiv...
# (408, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20021205, End Date: 20021215
# Downloading data from refinitiv...
# ERROR!!! An error occurred while requesting URL('https://api.refinitiv.com/data/datagrid/beta1/').
#      ReadTimeout('')
# An error occurred: . Retrying for the range 20021205 to 20021215...
# Start Date: 20021205, End Date: 20021215
# Downloading data from refinitiv...
# ERROR!!! An error occurred while requesting URL('https://api.refinitiv.com/data/datagrid/beta1/').
#      ReadTimeout('')
# An error occurred: . Retrying for the range 20021205 to 20021215...
# Start Date: 20021205, End Date: 20021215
# Downloading data from refinitiv...
# (381, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20021216, End Date: 20021226
# Downloading data from refinitiv...
# (539, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20021227, End Date: 20030106
# Downloading data from refinitiv...
# (379, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20030107, End Date: 20030117
# Downloading data from refinitiv...
# (425, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20030118, End Date: 20030128
# Downloading data from refinitiv...
# (384, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20030129, End Date: 20030208
# Downloading data from refinitiv...
# ERROR!!! An error occurred while requesting URL('https://api.refinitiv.com/data/datagrid/beta1/').
#      ReadTimeout('')
# An error occurred: . Retrying for the range 20030129 to 20030208...
# Start Date: 20030129, End Date: 20030208
# Downloading data from refinitiv...
# ERROR!!! An error occurred while requesting URL('https://api.refinitiv.com/data/datagrid/beta1/').
#      ReadTimeout('')
# An error occurred: . Retrying for the range 20030129 to 20030208...
# Start Date: 20030129, End Date: 20030208
# Downloading data from refinitiv...
# ERROR!!! An error occurred while requesting URL('https://api.refinitiv.com/data/datagrid/beta1/').
#      ReadTimeout('')
# An error occurred: . Retrying for the range 20030129 to 20030208...
# Start Date: 20030129, End Date: 20030208
# Downloading data from refinitiv...
# (503, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20030209, End Date: 20030219
# Downloading data from refinitiv...
# (374, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20030220, End Date: 20030302
# Downloading data from refinitiv...
# (392, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20030303, End Date: 20030313
# Downloading data from refinitiv...
# ERROR!!! An error occurred while requesting URL('https://api.refinitiv.com/data/datagrid/beta1/').
#      ReadTimeout('')
# An error occurred: . Retrying for the range 20030303 to 20030313...
# Start Date: 20030303, End Date: 20030313
# Downloading data from refinitiv...
# (521, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20030314, End Date: 20030324
# Downloading data from refinitiv...
# ERROR!!! An error occurred while requesting URL('https://api.refinitiv.com/data/datagrid/beta1/').
#      ReadTimeout('')
# An error occurred: . Retrying for the range 20030314 to 20030324...
# Start Date: 20030314, End Date: 20030324
# Downloading data from refinitiv...
# ERROR!!! An error occurred while requesting URL('https://api.refinitiv.com/data/datagrid/beta1/').
#      ReadTimeout('')
# An error occurred: . Retrying for the range 20030314 to 20030324...
# Start Date: 20030314, End Date: 20030324
# Downloading data from refinitiv...
# ERROR!!! An error occurred while requesting URL('https://api.refinitiv.com/data/datagrid/beta1/').
#      ReadTimeout('')
# An error occurred: . Retrying for the range 20030314 to 20030324...
# Start Date: 20030314, End Date: 20030324
# Downloading data from refinitiv...
# (379, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20030325, End Date: 20030404
# Downloading data from refinitiv...
# (598, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20030405, End Date: 20030415
# Downloading data from refinitiv...
# (382, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20030416, End Date: 20030426
# Downloading data from refinitiv...
# (427, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20030427, End Date: 20030507
# Downloading data from refinitiv...
# (463, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20030508, End Date: 20030518
# Downloading data from refinitiv...
# (353, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20030519, End Date: 20030529
# Downloading data from refinitiv...
# (524, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20030530, End Date: 20030609
# Downloading data from refinitiv...
# (473, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20030610, End Date: 20030620
# Downloading data from refinitiv...
# (458, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20030621, End Date: 20030701
# Downloading data from refinitiv...
# (521, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20030702, End Date: 20030712
# Downloading data from refinitiv...
# (455, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20030713, End Date: 20030723
# Downloading data from refinitiv...
# (462, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20030724, End Date: 20030803
# Downloading data from refinitiv...
# (462, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20030804, End Date: 20030814
# Downloading data from refinitiv...
# ERROR!!! An error occurred while requesting URL('https://api.refinitiv.com/data/datagrid/beta1/').
#      ReadTimeout('')
# An error occurred: . Retrying for the range 20030804 to 20030814...
# Start Date: 20030804, End Date: 20030814
# Downloading data from refinitiv...
# (456, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20030815, End Date: 20030825
# Downloading data from refinitiv...
# (402, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20030826, End Date: 20030905
# Downloading data from refinitiv...
# (526, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20030906, End Date: 20030916
# Downloading data from refinitiv...
# (396, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20030917, End Date: 20030927
# Downloading data from refinitiv...
# (505, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20030928, End Date: 20031008
# Downloading data from refinitiv...
# (627, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20031009, End Date: 20031019
# Downloading data from refinitiv...
# (448, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20031020, End Date: 20031030
# Downloading data from refinitiv...
# (527, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20031031, End Date: 20031110
# Downloading data from refinitiv...
# (435, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20031111, End Date: 20031121
# Downloading data from refinitiv...
# (533, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20031122, End Date: 20031202
# Downloading data from refinitiv...
# (489, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20031203, End Date: 20031213
# Downloading data from refinitiv...
# (465, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20031214, End Date: 20031224
# Downloading data from refinitiv...
# (666, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20031225, End Date: 20040104
# Downloading data from refinitiv...
# (319, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20040105, End Date: 20040115
# Downloading data from refinitiv...
# (496, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20040116, End Date: 20040126
# Downloading data from refinitiv...
# (421, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20040127, End Date: 20040206
# Downloading data from refinitiv...
# (622, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20040207, End Date: 20040217
# Downloading data from refinitiv...
# (411, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20040218, End Date: 20040228
# Downloading data from refinitiv...
# (472, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20040229, End Date: 20040310
# Downloading data from refinitiv...
# (607, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20040311, End Date: 20040321
# Downloading data from refinitiv...
# (472, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20040322, End Date: 20040401
# Downloading data from refinitiv...
# (721, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20040402, End Date: 20040412
# Downloading data from refinitiv...
# (388, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20040413, End Date: 20040423
# Downloading data from refinitiv...
# (503, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20040424, End Date: 20040504
# Downloading data from refinitiv...
# (495, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20040505, End Date: 20040515
# Downloading data from refinitiv...
# (467, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20040516, End Date: 20040526
# Downloading data from refinitiv...
# (533, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20040527, End Date: 20040606
# Downloading data from refinitiv...
# (479, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20040607, End Date: 20040617
# Downloading data from refinitiv...
# (473, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20040618, End Date: 20040628
# Downloading data from refinitiv...
# ERROR!!! An error occurred while requesting URL('https://api.refinitiv.com/data/datagrid/beta1/').
#      ReadTimeout('')
# An error occurred: . Retrying for the range 20040618 to 20040628...
# Start Date: 20040618, End Date: 20040628
# Downloading data from refinitiv...
# (424, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20040629, End Date: 20040709
# Downloading data from refinitiv...
# ERROR!!! An error occurred while requesting URL('https://api.refinitiv.com/data/datagrid/beta1/').
#      ReadTimeout('')
# An error occurred: . Retrying for the range 20040629 to 20040709...
# Start Date: 20040629, End Date: 20040709
# Downloading data from refinitiv...
# ERROR!!! An error occurred while requesting URL('https://api.refinitiv.com/data/datagrid/beta1/').
#      ReadTimeout('')
# An error occurred: . Retrying for the range 20040629 to 20040709...
# Start Date: 20040629, End Date: 20040709
# Downloading data from refinitiv...
# (645, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20040710, End Date: 20040720
# Downloading data from refinitiv...
# (424, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20040721, End Date: 20040731
# Downloading data from refinitiv...
# (535, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20040801, End Date: 20040811
# Downloading data from refinitiv...
# (450, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20040812, End Date: 20040822
# Downloading data from refinitiv...
# (378, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20040823, End Date: 20040902
# Downloading data from refinitiv...
# ERROR!!! An error occurred while requesting URL('https://api.refinitiv.com/data/datagrid/beta1/').
#      ReadTimeout('')
# An error occurred: . Retrying for the range 20040823 to 20040902...
# Start Date: 20040823, End Date: 20040902
# Downloading data from refinitiv...
# (491, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20040903, End Date: 20040913
# Downloading data from refinitiv...
# (391, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20040914, End Date: 20040924
# Downloading data from refinitiv...
# (464, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20040925, End Date: 20041005
# Downloading data from refinitiv...
# (596, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20041006, End Date: 20041016
# Downloading data from refinitiv...
# (393, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20041017, End Date: 20041027
# Downloading data from refinitiv...
# (496, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20041028, End Date: 20041107
# Downloading data from refinitiv...
# (447, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20041108, End Date: 20041118
# Downloading data from refinitiv...
# (561, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20041119, End Date: 20041129
# Downloading data from refinitiv...
# (431, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20041130, End Date: 20041210
# Downloading data from refinitiv...
# (625, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20041211, End Date: 20041221
# Downloading data from refinitiv...
# (578, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20041222, End Date: 20050101
# Downloading data from refinitiv...
# (645, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20050102, End Date: 20050112
# Downloading data from refinitiv...
# (401, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20050113, End Date: 20050123
# Downloading data from refinitiv...
# (445, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20050124, End Date: 20050203
# Downloading data from refinitiv...
# (669, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20050204, End Date: 20050214
# Downloading data from refinitiv...
# ERROR!!! An error occurred while requesting URL('https://api.refinitiv.com/data/datagrid/beta1/').
#      ReadTimeout('')
# An error occurred: . Retrying for the range 20050204 to 20050214...
# Start Date: 20050204, End Date: 20050214
# Downloading data from refinitiv...
# (443, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20050215, End Date: 20050225
# Downloading data from refinitiv...
# (537, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20050226, End Date: 20050308
# Downloading data from refinitiv...
# (580, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20050309, End Date: 20050319
# Downloading data from refinitiv...
# (545, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20050320, End Date: 20050330
# Downloading data from refinitiv...
# (516, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20050331, End Date: 20050410
# Downloading data from refinitiv...
# ERROR!!! An error occurred while requesting URL('https://api.refinitiv.com/data/datagrid/beta1/').
#      ReadTimeout('')
# An error occurred: . Retrying for the range 20050331 to 20050410...
# Start Date: 20050331, End Date: 20050410
# Downloading data from refinitiv...
# ERROR!!! An error occurred while requesting URL('https://api.refinitiv.com/data/datagrid/beta1/').
#      ReadTimeout('')
# An error occurred: . Retrying for the range 20050331 to 20050410...
# Start Date: 20050331, End Date: 20050410
# Downloading data from refinitiv...
# (548, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20050411, End Date: 20050421
# Downloading data from refinitiv...
# (584, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20050422, End Date: 20050502
# Downloading data from refinitiv...
# (586, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20050503, End Date: 20050513
# Downloading data from refinitiv...
# (518, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20050514, End Date: 20050524
# Downloading data from refinitiv...
# (467, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20050525, End Date: 20050604
# Downloading data from refinitiv...
# (582, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20050605, End Date: 20050615
# Downloading data from refinitiv...
# ERROR!!! An error occurred while requesting URL('https://api.refinitiv.com/data/datagrid/beta1/').
#      ReadTimeout('')
# An error occurred: . Retrying for the range 20050605 to 20050615...
# Start Date: 20050605, End Date: 20050615
# Downloading data from refinitiv...
# (514, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20050616, End Date: 20050626
# Downloading data from refinitiv...
# (516, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20050627, End Date: 20050707
# Downloading data from refinitiv...
# (792, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20050708, End Date: 20050718
# Downloading data from refinitiv...
# (457, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20050719, End Date: 20050729
# Downloading data from refinitiv...
# ERROR!!! An error occurred while requesting URL('https://api.refinitiv.com/data/datagrid/beta1/').
#      ReadTimeout('')
# An error occurred: . Retrying for the range 20050719 to 20050729...
# Start Date: 20050719, End Date: 20050729
# Downloading data from refinitiv...
# (623, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20050730, End Date: 20050809
# Downloading data from refinitiv...
# (535, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20050810, End Date: 20050820
# Downloading data from refinitiv...
# (529, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20050821, End Date: 20050831
# Downloading data from refinitiv...
# (567, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20050901, End Date: 20050911
# Downloading data from refinitiv...
# (524, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20050912, End Date: 20050922
# Downloading data from refinitiv...
# (671, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20050923, End Date: 20051003
# Downloading data from refinitiv...
# (620, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20051004, End Date: 20051014
# Downloading data from refinitiv...
# (631, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20051015, End Date: 20051025
# Downloading data from refinitiv...
# (474, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20051026, End Date: 20051105
# Downloading data from refinitiv...
# ERROR!!! An error occurred while requesting URL('https://api.refinitiv.com/data/datagrid/beta1/').
#      ReadTimeout('')
# An error occurred: . Retrying for the range 20051026 to 20051105...
# Start Date: 20051026, End Date: 20051105
# Downloading data from refinitiv...
# (586, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20051106, End Date: 20051116
# Downloading data from refinitiv...
# (566, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20051117, End Date: 20051127
# Downloading data from refinitiv...
# (439, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20051128, End Date: 20051208
# Downloading data from refinitiv...
# (787, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20051209, End Date: 20051219
# Downloading data from refinitiv...
# (626, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20051220, End Date: 20051230
# Downloading data from refinitiv...
# (675, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20051231, End Date: 20060110
# Downloading data from refinitiv...
# (447, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20060111, End Date: 20060121
# Downloading data from refinitiv...
# (516, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20060122, End Date: 20060201
# Downloading data from refinitiv...
# (661, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20060202, End Date: 20060212
# Downloading data from refinitiv...
# (526, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20060213, End Date: 20060223
# Downloading data from refinitiv...
# (671, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20060224, End Date: 20060306
# Downloading data from refinitiv...
# (642, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20060307, End Date: 20060317
# Downloading data from refinitiv...
# (673, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20060318, End Date: 20060328
# Downloading data from refinitiv...
# ERROR!!! An error occurred while requesting URL('https://api.refinitiv.com/data/datagrid/beta1/').
#      ReadTimeout('')
# An error occurred: . Retrying for the range 20060318 to 20060328...
# Start Date: 20060318, End Date: 20060328
# Downloading data from refinitiv...
# (567, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20060329, End Date: 20060408
# Downloading data from refinitiv...
# (831, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20060409, End Date: 20060419
# Downloading data from refinitiv...
# ERROR!!! An error occurred while requesting URL('https://api.refinitiv.com/data/datagrid/beta1/').
#      ReadTimeout('')
# An error occurred: . Retrying for the range 20060409 to 20060419...
# Start Date: 20060409, End Date: 20060419
# Downloading data from refinitiv...
# (486, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20060420, End Date: 20060430
# Downloading data from refinitiv...
# (612, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20060501, End Date: 20060511
# Downloading data from refinitiv...
# (723, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20060512, End Date: 20060522
# Downloading data from refinitiv...
# (574, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20060523, End Date: 20060602
# Downloading data from refinitiv...
# (784, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20060603, End Date: 20060613
# Downloading data from refinitiv...
# ERROR!!! An error occurred while requesting URL('https://api.refinitiv.com/data/datagrid/beta1/').
#      ReadTimeout('')
# An error occurred: . Retrying for the range 20060603 to 20060613...
# Start Date: 20060603, End Date: 20060613
# Downloading data from refinitiv...
# (490, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20060614, End Date: 20060624
# Downloading data from refinitiv...
# (587, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20060625, End Date: 20060705
# Downloading data from refinitiv...
# (792, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20060706, End Date: 20060716
# Downloading data from refinitiv...
# (525, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20060717, End Date: 20060727
# Downloading data from refinitiv...
# ERROR!!! An error occurred while requesting URL('https://api.refinitiv.com/data/datagrid/beta1/').
#      ReadTimeout('')
# An error occurred: . Retrying for the range 20060717 to 20060727...
# Start Date: 20060717, End Date: 20060727
# Downloading data from refinitiv...
# (729, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20060728, End Date: 20060807
# Downloading data from refinitiv...
# (617, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20060808, End Date: 20060818
# Downloading data from refinitiv...
# ERROR!!! An error occurred while requesting URL('https://api.refinitiv.com/data/datagrid/beta1/').
#      ReadTimeout('')
# An error occurred: . Retrying for the range 20060808 to 20060818...
# Start Date: 20060808, End Date: 20060818
# Downloading data from refinitiv...
# (571, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20060819, End Date: 20060829
# Downloading data from refinitiv...
# (522, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20060830, End Date: 20060909
# Downloading data from refinitiv...
# (680, 20)
# Uploading data to BQ...
# Data appended successfully.
# Start Date: 20060910, End Date: 20060920
# Downloading data from refinitiv...
# ERROR!!! An error occurred while requesting URL('https://api.refinitiv.com/data/datagrid/beta1/').
#      ReadTimeout('')
# ...
# Start Date: 20240617, End Date: 20240627
# Downloading data from refinitiv...
# (0, 0)
# Uploading data to BQ...
# An error occurred: 400 Table refinitiv_deals_8e9e0d7b_db03_4899_817e_7e40ac43fb8d_source does not have a schema.; reason: invalid, message: Table refinitiv_deals_8e9e0d7b_db03_4899_817e_7e40ac43fb8d_source does not have a schema.. Retrying for the range 20240617 to 20240627...
# Start Date: 20240617, End Date: 20240627
# Downloading data from refinitiv...
# (0, 0)
# Uploading data to BQ...
# An error occurred: 400 Table refinitiv_deals_23ac9110_e4be_47ee_be26_2a49b7a36a91_source does not have a schema.; reason: invalid, message: Table refinitiv_deals_23ac9110_e4be_47ee_be26_2a49b7a36a91_source does not have a schema.. Retrying for the range 20240617 to 20240627...
# Start Date: 20240617, End Date: 20240627
# Downloading data from refinitiv...
# (0, 0)
# Uploading data to BQ...
# An error occurred: 400 Table refinitiv_deals_ff43ee61_7270_4cbd_bcbe_fdc329d93600_source does not have a schema.; reason: invalid, message: Table refinitiv_deals_ff43ee61_7270_4cbd_bcbe_fdc329d93600_source does not have a schema.. Retrying for the range 20240617 to 20240627...
# Start Date: 20240617, End Date: 20240627
# Downloading data from refinitiv...
# (0, 0)
# Uploading data to BQ...
# An error occurred: 400 Table refinitiv_deals_2be53b86_611d_4209_bd6a_bfbc81a639ea_source does not have a schema.; reason: invalid, message: Table refinitiv_deals_2be53b86_611d_4209_bd6a_bfbc81a639ea_source does not have a schema.. Retrying for the range 20240617 to 20240627...
# Start Date: 20240617, End Date: 20240627
# Downloading data from refinitiv...
# (0, 0)
# Uploading data to BQ...
# An error occurred: 400 Table refinitiv_deals_20c0050b_5423_467a_95a5_c4977dc9628f_source does not have a schema.; reason: invalid, message: Table refinitiv_deals_20c0050b_5423_467a_95a5_c4977dc9628f_source does not have a schema.. Retrying for the range 20240617 to 20240627...
# Start Date: 20240617, End Date: 20240627
# Downloading data from refinitiv...
# (0, 0)
# Uploading data to BQ...
# An error occurred: 400 Table refinitiv_deals_bc3883be_fc78_4ecb_8cf9_0cfba1d0c80b_source does not have a schema.; reason: invalid, message: Table refinitiv_deals_bc3883be_fc78_4ecb_8cf9_0cfba1d0c80b_source does not have a schema.. Retrying for the range 20240617 to 20240627...
# Start Date: 20240617, End Date: 20240627
# Downloading data from refinitiv...
# (0, 0)
# Uploading data to BQ...
# An error occurred: 400 Table refinitiv_deals_83c2283b_49aa_4e5c_abac_404936393b32_source does not have a schema.; reason: invalid, message: Table refinitiv_deals_83c2283b_49aa_4e5c_abac_404936393b32_source does not have a schema.. Retrying for the range 20240617 to 20240627...
# Start Date: 20240617, End Date: 20240627
# Downloading data from refinitiv...
# (0, 0)
# Uploading data to BQ...
# An error occurred: 400 Table refinitiv_deals_530e1b7b_3493_4b87_b8c2_b9f5a1ea1306_source does not have a schema.; reason: invalid, message: Table refinitiv_deals_530e1b7b_3493_4b87_b8c2_b9f5a1ea1306_source does not have a schema.. Retrying for the range 20240617 to 20240627...
# Start Date: 20240617, End Date: 20240627
# Downloading data from refinitiv...
# (0, 0)
# Uploading data to BQ...
# An error occurred: 400 Table refinitiv_deals_970b67b7_cc01_41ae_b811_ff72ebfc7edc_source does not have a schema.; reason: invalid, message: Table refinitiv_deals_970b67b7_cc01_41ae_b811_ff72ebfc7edc_source does not have a schema.. Retrying for the range 20240617 to 20240627...
# Start Date: 20240617, End Date: 20240627
# Downloading data from refinitiv...
# (0, 0)
# Uploading data to BQ...
# An error occurred: 400 Table refinitiv_deals_2d5de5b9_a7a8_4e5b_b4bf_73cbeba16a81_source does not have a schema.; reason: invalid, message: Table refinitiv_deals_2d5de5b9_a7a8_4e5b_b4bf_73cbeba16a81_source does not have a schema.. Retrying for the range 20240617 to 20240627...
# Start Date: 20240617, End Date: 20240627
# Downloading data from refinitiv...
# (0, 0)
# Uploading data to BQ...
# An error occurred: 400 Table refinitiv_deals_6a46b161_f03b_4809_b33f_31cf5354de7f_source does not have a schema.; reason: invalid, message: Table refinitiv_deals_6a46b161_f03b_4809_b33f_31cf5354de7f_source does not have a schema.. Retrying for the range 20240617 to 20240627...
# Start Date: 20240617, End Date: 20240627
# Downloading data from refinitiv...
# (0, 0)
# Uploading data to BQ...
# An error occurred: 400 Table refinitiv_deals_39c71822_edbc_4349_839b_1a60d27bca6a_source does not have a schema.; reason: invalid, message: Table refinitiv_deals_39c71822_edbc_4349_839b_1a60d27bca6a_source does not have a schema.. Retrying for the range 20240617 to 20240627...
# Start Date: 20240617, End Date: 20240627
# Downloading data from refinitiv...
# (0, 0)
# Uploading data to BQ...
# An error occurred: 400 Table refinitiv_deals_6c6b2355_86dc_4c97_bfce_a52a7e783cbd_source does not have a schema.; reason: invalid, message: Table refinitiv_deals_6c6b2355_86dc_4c97_bfce_a52a7e783cbd_source does not have a schema.. Retrying for the range 20240617 to 20240627...
# Start Date: 20240617, End Date: 20240627
# Downloading data from refinitiv...
# (0, 0)
# Uploading data to BQ...
# An error occurred: 400 Table refinitiv_deals_9e132d96_85bb_415a_977a_4af9041a6431_source does not have a schema.; reason: invalid, message: Table refinitiv_deals_9e132d96_85bb_415a_977a_4af9041a6431_source does not have a schema.. Retrying for the range 20240617 to 20240627...
# Start Date: 20240617, End Date: 20240627
# Downloading data from refinitiv...
# (0, 0)
# Uploading data to BQ...
# An error occurred: 400 Table refinitiv_deals_32f9bcd1_c236_4c3e_802f_1f06f4f5ddc7_source does not have a schema.; reason: invalid, message: Table refinitiv_deals_32f9bcd1_c236_4c3e_802f_1f06f4f5ddc7_source does not have a schema.. Retrying for the range 20240617 to 20240627...
# Start Date: 20240617, End Date: 20240627
# Downloading data from refinitiv...
# (0, 0)
# Uploading data to BQ...
# An error occurred: 400 Table refinitiv_deals_495abd37_4da5_4f01_be28_961700985850_source does not have a schema.; reason: invalid, message: Table refinitiv_deals_495abd37_4da5_4f01_be28_961700985850_source does not have a schema.. Retrying for the range 20240617 to 20240627...
# Start Date: 20240617, End Date: 20240627
# Downloading data from refinitiv...
# (0, 0)
# Uploading data to BQ...
# An error occurred: 400 Table refinitiv_deals_06897c87_cacc_4515_acda_6f3e97b1db7a_source does not have a schema.; reason: invalid, message: Table refinitiv_deals_06897c87_cacc_4515_acda_6f3e97b1db7a_source does not have a schema.. Retrying for the range 20240617 to 20240627...
# Start Date: 20240617, End Date: 20240627
# Downloading data from refinitiv...
# (0, 0)
# Uploading data to BQ...
# An error occurred: 400 Table refinitiv_deals_22a4e2c5_7041_41bf_b43c_28ccd619d3c1_source does not have a schema.; reason: invalid, message: Table refinitiv_deals_22a4e2c5_7041_41bf_b43c_28ccd619d3c1_source does not have a schema.. Retrying for the range 20240617 to 20240627...
# Start Date: 20240617, End Date: 20240627
# Downloading data from refinitiv...
# (0, 0)
# Uploading data to BQ...
# An error occurred: 400 Table refinitiv_deals_7c632584_a125_4682_8024_d750faaa2b99_source does not have a schema.; reason: invalid, message: Table refinitiv_deals_7c632584_a125_4682_8024_d750faaa2b99_source does not have a schema.. Retrying for the range 20240617 to 20240627...
# Start Date: 20240617, End Date: 20240627
# Downloading data from refinitiv...
# (0, 0)
# Uploading data to BQ...
# An error occurred: 400 Table refinitiv_deals_7c4c0d2f_fdd2_4786_927a_a8c315862b1d_source does not have a schema.; reason: invalid, message: Table refinitiv_deals_7c4c0d2f_fdd2_4786_927a_a8c315862b1d_source does not have a schema.. Retrying for the range 20240617 to 20240627...
# Start Date: 20240617, End Date: 20240627
# Downloading data from refinitiv...
# (0, 0)
# Uploading data to BQ...
# An error occurred: 400 Table refinitiv_deals_452ba44f_5950_46e8_b1bc_11645b09cf82_source does not have a schema.; reason: invalid, message: Table refinitiv_deals_452ba44f_5950_46e8_b1bc_11645b09cf82_source does not have a schema.. Retrying for the range 20240617 to 20240627...
# Start Date: 20240617, End Date: 20240627
# Downloading data from refinitiv...
# (0, 0)
# Uploading data to BQ...
# An error occurred: 400 Table refinitiv_deals_fe5a6e8b_c7ec_4492_b608_0cfcdf35bddf_source does not have a schema.; reason: invalid, message: Table refinitiv_deals_fe5a6e8b_c7ec_4492_b608_0cfcdf35bddf_source does not have a schema.. Retrying for the range 20240617 to 20240627...
# Start Date: 20240617, End Date: 20240627
# Downloading data from refinitiv...
# (0, 0)
# Uploading data to BQ...
# An error occurred: 400 Table refinitiv_deals_c6eae6dc_fe8d_4f28_87f2_cd907da0e4cf_source does not have a schema.; reason: invalid, message: Table refinitiv_deals_c6eae6dc_fe8d_4f28_87f2_cd907da0e4cf_source does not have a schema.. Retrying for the range 20240617 to 20240627...
# Start Date: 20240617, End Date: 20240627
# Downloading data from refinitiv...
# (0, 0)
# Uploading data to BQ...
# An error occurred: 400 Table refinitiv_deals_4ab074bf_9160_4cd8_8b74_eed268b6700c_source does not have a schema.; reason: invalid, message: Table refinitiv_deals_4ab074bf_9160_4cd8_8b74_eed268b6700c_source does not have a schema.. Retrying for the range 20240617 to 20240627...
# Start Date: 20240617, End Date: 20240627
# Downloading data from refinitiv...
# (0, 0)
# Uploading data to BQ...
# An error occurred: 400 Table refinitiv_deals_a037ee04_e4b8_4a41_ab5d_6ec02f15c040_source does not have a schema.; reason: invalid, message: Table refinitiv_deals_a037ee04_e4b8_4a41_ab5d_6ec02f15c040_source does not have a schema.. Retrying for the range 20240617 to 20240627...
# Start Date: 20240617, End Date: 20240627
# Downloading data from refinitiv...
# (0, 0)
# Uploading data to BQ...
# An error occurred: 400 Table refinitiv_deals_bb7ba00a_5134_420b_b2bf_23abbc05f850_source does not have a schema.; reason: invalid, message: Table refinitiv_deals_bb7ba00a_5134_420b_b2bf_23abbc05f850_source does not have a schema.. Retrying for the range 20240617 to 20240627...
# Start Date: 20240617, End Date: 20240627
# Downloading data from refinitiv...
# (0, 0)
# Uploading data to BQ...
# An error occurred: 400 Table refinitiv_deals_71d28099_d10a_482c_99da_4d169fdba9d0_source does not have a schema.; reason: invalid, message: Table refinitiv_deals_71d28099_d10a_482c_99da_4d169fdba9d0_source does not have a schema.. Retrying for the range 20240617 to 20240627...
# Start Date: 20240617, End Date: 20240627
# Downloading data from refinitiv...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[133], line 54
#      45 mna_screen = f'SCREEN(U(IN(DEALS)/*UNV:DEALSMNA*/),\
#      46             BETWEEN(TR.MnAAnnDate,{start},{end})/*dt:Date*/, \
#      47             IN(TR.MnAType(Concat="|"), "1", "10", "11", "12"),\
#      48             NOT_IN(TR.MnAAcquirorNation, "CN"),\
#      49             NOT_IN(TR.MnAStatus, "S", "R", "DR", "W", "SW"), \
#      50             CURN=USD)'
#      53 # input ipo screen results as instrument list and pull ipo attributes via fields from Eikon Data API.
# ---> 54 mnas = rdp.get_data(mna_screen, ['TR.MnASDCDealNumber',
#      55                                'TR.MnAAnnDate',
#      56                                'TR.MnARankValueIncNetDebt(Curn=USD,Scale=6)',
#      57                                'TR.MnADealValue(Curn=USD,Scale=6)', 'TR.MnADealCurrency',
#      58                                'TR.MnADealType',
#      59                                'TR.MnATarget', 'TR.MnATargetNation', 'TR.MnATargetSDCCusip',
#      60                                'TR.MnAAcquiror', 'TR.MnAAcquirorNation', 'TR.MnAAcquirorSDCCusip',
#      61                                'TR.MnAAcquirorUltParent', 'TR.MnAAcquirorUltParentSDCCusip',
#      62                                'TR.MnAPctHeldAtAnnDate', 'TR.MnAPctOfSharesAcquired', 'TR.MnAPctOfSharesAcqSeeksToOwn',
#      63                                'TR.MnAStatus',
#      64                                'TR.MnACompDealId(Concat="|")'])
#      65 print(mnas.shape)
#      67 print("Uploading data to BQ...")
#
# File /opt/conda/lib/python3.10/site-packages/refinitiv/dataplatform/content/data_grid/_functions.py:80, in get_data(universe, fields, parameters, field_name)
#       9 def get_data(
#      10     universe,
#      11     fields,
#      12     parameters=None,
#      13     field_name=None,
#      14 ):
#      15     """
#      16     Returns a pandas.DataFrame with fields in columns and instruments as row index
#      17
#    (...)
#      77     >>> data = rdp.get_data(["IBM","MSFT.O"], fields)
#      78     """
# ---> 80     result = Fundamental.get_data(
#      81         universe=universe,
#      82         fields=fields,
#      83         parameters=parameters,
#      84         field_name=field_name,
#      85     )
#      86     from refinitiv.dataplatform.factory.content_factory import ContentFactory
#      88     if result.is_success and result.data and result.data.df is not None:
#
# File /opt/conda/lib/python3.10/site-packages/refinitiv/dataplatform/content/data_grid/_fundamental_class.py:67, in Fundamental.get_data(universe, fields, parameters, field_name, on_response, closure, session)
#      56 @staticmethod
#      57 def get_data(
#      58     universe,
#    (...)
#      64     session=None,
#      65 ):
#      66     fundamental = Fundamental(session=session, on_response=on_response)
# ---> 67     result = fundamental._get_data(
#      68         universe=universe,
#      69         fields=fields,
#      70         parameters=parameters,
#      71         field_name=field_name,
#      72         closure=None,
#      73         session=None,
#      74     )
#      75     return result
#
# File /opt/conda/lib/python3.10/site-packages/refinitiv/dataplatform/content/data_grid/_fundamental_class.py:94, in Fundamental._get_data(self, universe, fields, parameters, field_name, closure, session)
#      77 def _get_data(
#      78     self,
#      79     universe,
#    (...)
#      84     session=None,
#      85 ):
#      86     """
#      87     :param universe: list    The list of RICs
#      88     :param fields: list      List of fundamental field names
#    (...)
#      92     :return:Response
#      93     """
# ---> 94     result = self._run_until_complete(
#      95         self._get_data_async(
#      96             universe=universe,
#      97             fields=fields,
#      98             parameters=parameters,
#      99             field_name=field_name,
#     100             closure=closure,
#     101         )
#     102     )
#     103     return result
#
# File /opt/conda/lib/python3.10/site-packages/refinitiv/dataplatform/content/data_grid/_fundamental_class.py:54, in Fundamental._run_until_complete(self, future)
#      53 def _run_until_complete(self, future):
# ---> 54     return self._endpoint.session._loop.run_until_complete(future)
#
# File /opt/conda/lib/python3.10/site-packages/nest_asyncio.py:92, in _patch_loop.<locals>.run_until_complete(self, future)
#      90     f._log_destroy_pending = False
#      91 while not f.done():
# ---> 92     self._run_once()
#      93     if self._stopping:
#      94         break
#
# File /opt/conda/lib/python3.10/site-packages/nest_asyncio.py:115, in _patch_loop.<locals>._run_once(self)
#     108     heappop(scheduled)
#     110 timeout = (
#     111     0 if ready or self._stopping
#     112     else min(max(
#     113         scheduled[0]._when - self.time(), 0), 86400) if scheduled
#     114     else None)
# --> 115 event_list = self._selector.select(timeout)
#     116 self._process_events(event_list)
#     118 end_time = self.time() + self._clock_resolution
#
# File /opt/conda/lib/python3.10/selectors.py:469, in EpollSelector.select(self, timeout)
#     467 ready = []
#     468 try:
# --> 469     fd_event_list = self._selector.poll(timeout, max_ev)
#     470 except InterruptedError:
#     471     return ready
#
# KeyboardInterrupt:

# %%
# # Initialize a BigQuery client
# client = bigquery.Client()

# # Define your project, dataset, and table
# project_id = "starfire-410116"
# dataset_id = "derived"
# table_id = "refinitiv_deals_2"


# # Construct a reference to the target table
# table_ref = client.dataset(dataset_id).table(table_id)

# # Configure the load job to append data to the existing table
# job_config = bigquery.LoadJobConfig(
#     write_disposition=bigquery.WriteDisposition.WRITE_APPEND
# )


master_df = pd.DataFrame()


from datetime import datetime, timedelta

# Initial start date
start_date = datetime.strptime('20180101', '%Y%m%d')

# Define the interval (15 days)
interval = timedelta(days=5)

# Initialize an empty list to store the date ranges
date_ranges = []

# Loop to create date intervals
for _ in range(10000):  # Adjust the range to get the desired number of intervals
    end_date = start_date + interval
    date_ranges.append((start_date.strftime('%Y%m%d'), end_date.strftime('%Y%m%d')))
    start_date = end_date + timedelta(days=1)

# Print the date ranges
for start, end in date_ranges:
    success = False
    while not success:
        try:
            print(f"Start Date: {start}, End Date: {end}")

            print("Downloading data from refinitiv...")

            mna_screen = f'SCREEN(U(IN(DEALS)/*UNV:DEALSMNA*/),\
                        BETWEEN(TR.MnAAnnDate,{start},{end})/*dt:Date*/, \
                        CURN=USD)'


            # input ipo screen results as instrument list and pull ipo attributes via fields from Eikon Data API. 
            mnas = rdp.get_data(mna_screen,['TR.MNASDCDealNumber',
                                            'TR.MnAAnnDate', 'TR.MnARankValueIncNetDebt(Curn=USD,Scale=6)',
                                            'TR.MnATarget', 'TR.MnATargetPermId',
                                            'TR.MnATargetPriTickerSym',
                                            'TR.MnATargetNation',
                                            'TR.MnATargetMacroInd',
                                            'TR.MnATargetMidInd',
                                            'TR.MnAAcquiror',
                                            'TR.MnAAcquirorPermId',
                                            'TR.MnAAcquirorMacroInd',
                                            'TR.MnAAcquirorMidInd',
                                            'TR.MnAAcquirorNation',
                                            'TR.MNADealId','TR.MnASynopsis',
                                            'TR.MnAAcquirorPriHiTech',
                                            'TR.MnAAcquirorPriTickerSym',
                                            'TR.MnAAcquirorExchTicker(Concat="|")',
                                            'TR.MnAAcquirorUltParentPermID',
                                            'TR.MnAHiTechGroup(Concat="|")',
                                            'TR.MnaAcquirorDate1DayPriorToAnn',
                                            'TR.MnaAcquirorStockPrice1DayPriorToAnnInAcqCurr(Curn=USD),
                                            'TR.MnAAcquirorStockPriceOnAnn(Curn=USD)',
                                            'TR.MnAAcquirorStockPrice1DayPostAnn(Curn=USD)',
                                            'TR.MnASnP5001DayPreAnn',
                                            'TR.MnASnP500AtAnnouncement',
                                            'TR.MnASnP5001DayPostAnn',
                                            'TR.MnATargetSDCCusip',
                                            'TR.MnAAcquirorSDCCusip',
                                            'TR.MnAAcquirorUltParentSDCCusip',
                                            'TR.MnAValueOfCash(Curn=USD, Scale=6)',
                                            'TR.MnAValueOfEarnout(Curn=USD, Scale=6)',
                                            'TR.MnADealValue(Curn=USD, Scale=6)',
                                            'TR.MnAAcquirorHiTech(Concat="|")',
                                            'TR.MnAAcquirorUltParentHiTech(Concat="|")',
                                            'TR.MnATargetPriHiTech',
                                            'TR.MnAAcquirorMajorInd',
                                            'TR.MnAAcquirorMajorIndGrp',
                                            'TR.MnAAcquirorPriVEIC',
                                            'TR.MnAMasterDealType',
                                            'TR.MnADealType',
                                            'TR.MnAType(Concat="|")',
                                            'TR.MnAAcquirorVeic(Concat="|")',
                                            'TR.MnAPurposeDescription',
                                            'TR.MnAIsCrossBorder',
                                            'TR.MnAAcquirorIsVentureFirm',
                                            'TR.MnATargetPriVEIC',
                                            'TR.MnATargetVeic(Concat="|")',
                                            'TR.MnAAcquirorBusDesc',
                                            'TR.MnATargetBusDesc',
                                            'TR.MnATargetExchTicker(Concat="|")',
                                            'TR.MnATargetUltParentSDCCusip',
                                            'TR.MnATargetUltParentPriTickerSym',
                                            'TR.MnATargetUltParentPermID',
                                            'TR.MnAAcquirorUltParentPriTickerSym',
                                            'TR.MnAAcquirorUltParentExchTicker(Concat="|")',
                                            'TR.MnATargetUltParentExchTicker(Concat="|")',
                                            'TR.MnATargetMajorInd',
                                            'TR.MnATargetMajorIndGrp',
                                            'TR.MnATargetHiTech(Concat="|")',
                                            'TR.MnAAcquirorUltParentPriHiTech',
                                            'TR.MnAAcquirorHiTechGroup(Concat="|")',
                                            'TR.MnATargetHiTechGroup(Concat="|")',
                                            'TR.MnAWithdrawnDate',
                                            'TR.MnADateUnconditional',
                                            'TR.MnAOrigAnnDate',
                                            'TR.MnAPercentCash',
                                            'TR.MnADealCurrency',
                                            'TR.MnAEarnoutDesc']) 

            print(mnas.shape)

#             print("Uploading data to BQ...")
#             mnas.columns = [col[3:].lower() for col in mnas.columns]

#             # Load the DataFrame into BigQuery
#             load_job = client.load_table_from_dataframe(mnas, table_ref, job_config=job_config)

#             # Wait for the load job to complete
#             load_job.result()

#             print("Data appended successfully.")

            master_df = pd.concat([master_df, mnas], ignore_index=True)
            print(f'Master shape: {master_df.shape}')
            print(master_df['TR.MNASDCDealNumber'])

            success = True 
            
        except Exception as e:
            print(f"An error occurred: {e}. Retrying for the range {start} to {end}...")
# Out:
# Start Date: 20180101, End Date: 20180106
# Downloading data from refinitiv...
# (978, 74)
# Master shape: (978, 74)
#     TR.MNASDCDealNumber TR.MNASDCDealNumber
# 0            2696976040          2696976040
# 1            2951155040          2951155040
# 2            3081061020          3081061020
# 3            3104001040          3104001040
# 4            3107974040          3107974040
# ..                  ...                 ...
# 973          4043055020          4043055020
# 974          4043106020          4043106020
# 975          4122965020          4122965020
# 976          4125712020          4125712020
# 977          4148128020          4148128020
#
# [978 rows x 2 columns]
# Start Date: 20180107, End Date: 20180112
# Downloading data from refinitiv...
# (1103, 74)
# Master shape: (2081, 74)
#      TR.MNASDCDealNumber TR.MNASDCDealNumber
# 0             2696976040          2696976040
# 1             2951155040          2951155040
# 2             3081061020          3081061020
# 3             3104001040          3104001040
# 4             3107974040          3107974040
# ...                  ...                 ...
# 2076          3648981020          3648981020
# 2077          3654915020          3654915020
# 2078          4079622040          4079622040
# 2079          4240998040          4240998040
# 2080          4254341020          4254341020
#
# [2081 rows x 2 columns]
# Start Date: 20180113, End Date: 20180118
# Downloading data from refinitiv...
# (885, 74)
# Master shape: (2966, 74)
#      TR.MNASDCDealNumber TR.MNASDCDealNumber
# 0             2696976040          2696976040
# 1             2951155040          2951155040
# 2             3081061020          3081061020
# 3             3104001040          3104001040
# 4             3107974040          3107974040
# ...                  ...                 ...
# 2961          3863498040          3863498040
# 2962          3991480020          3991480020
# 2963          4056981040          4056981040
# 2964          4131719040          4131719040
# 2965          4250216040          4250216040
#
# [2966 rows x 2 columns]
# Start Date: 20180119, End Date: 20180124
# Downloading data from refinitiv...
# ERROR!!! An error occurred while requesting URL('https://api.refinitiv.com/data/datagrid/beta1/').
#      ReadTimeout('')
# An error occurred: . Retrying for the range 20180119 to 20180124...
# Start Date: 20180119, End Date: 20180124
# Downloading data from refinitiv...
# ERROR!!! An error occurred while requesting URL('https://api.refinitiv.com/data/datagrid/beta1/').
#      ReadTimeout('')
# An error occurred: . Retrying for the range 20180119 to 20180124...
# Start Date: 20180119, End Date: 20180124
# Downloading data from refinitiv...
# (858, 74)
# Master shape: (3824, 74)
#      TR.MNASDCDealNumber TR.MNASDCDealNumber
# 0             2696976040          2696976040
# 1             2951155040          2951155040
# 2             3081061020          3081061020
# 3             3104001040          3104001040
# 4             3107974040          3107974040
# ...                  ...                 ...
# 3819          3671954040          3671954040
# 3820          3929770040          3929770040
# 3821          4124146040          4124146040
# 3822          4161506020          4161506020
# 3823          4223907040          4223907040
#
# [3824 rows x 2 columns]
# Start Date: 20180125, End Date: 20180130
# Downloading data from refinitiv...
# (876, 74)
# Master shape: (4700, 74)
#      TR.MNASDCDealNumber TR.MNASDCDealNumber
# 0             2696976040          2696976040
# 1             2951155040          2951155040
# 2             3081061020          3081061020
# 3             3104001040          3104001040
# 4             3107974040          3107974040
# ...                  ...                 ...
# 4695          3512325040          3512325040
# 4696          3721036020          3721036020
# 4697          4103997020          4103997020
# 4698          4127110020          4127110020
# 4699          4140549020          4140549020
#
# [4700 rows x 2 columns]
# Start Date: 20180131, End Date: 20180205
# Downloading data from refinitiv...
# (1180, 74)
# Master shape: (5880, 74)
#      TR.MNASDCDealNumber TR.MNASDCDealNumber
# 0             2696976040          2696976040
# 1             2951155040          2951155040
# 2             3081061020          3081061020
# 3             3104001040          3104001040
# 4             3107974040          3107974040
# ...                  ...                 ...
# 5875          3656788020          3656788020
# 5876          4024857020          4024857020
# 5877          4143665020          4143665020
# 5878          4156756020          4156756020
# 5879          4219681020          4219681020
#
# [5880 rows x 2 columns]
# Start Date: 20180206, End Date: 20180211
# Downloading data from refinitiv...
# (934, 74)
# Master shape: (6814, 74)
#      TR.MNASDCDealNumber TR.MNASDCDealNumber
# 0             2696976040          2696976040
# 1             2951155040          2951155040
# 2             3081061020          3081061020
# 3             3104001040          3104001040
# 4             3107974040          3107974040
# ...                  ...                 ...
# 6809          3644374020          3644374020
# 6810          3651951020          3651951020
# 6811          4041949040          4041949040
# 6812          4146478020          4146478020
# 6813          4237199040          4237199040
#
# [6814 rows x 2 columns]
# Start Date: 20180212, End Date: 20180217
# Downloading data from refinitiv...
# (981, 74)
# Master shape: (7795, 74)
#      TR.MNASDCDealNumber TR.MNASDCDealNumber
# 0             2696976040          2696976040
# 1             2951155040          2951155040
# 2             3081061020          3081061020
# 3             3104001040          3104001040
# 4             3107974040          3107974040
# ...                  ...                 ...
# 7790          3435849020          3435849020
# 7791          3656798020          3656798020
# 7792          3902262040          3902262040
# 7793          3923227040          3923227040
# 7794          4026054040          4026054040
#
# [7795 rows x 2 columns]
# Start Date: 20180218, End Date: 20180223
# Downloading data from refinitiv...
# ERROR!!! An error occurred while requesting URL('https://api.refinitiv.com/data/datagrid/beta1/').
#      ReadTimeout('')
# An error occurred: . Retrying for the range 20180218 to 20180223...
# Start Date: 20180218, End Date: 20180223
# Downloading data from refinitiv...
# ERROR!!! An error occurred while requesting URL('https://api.refinitiv.com/data/datagrid/beta1/').
#      ReadTimeout('')
# An error occurred: . Retrying for the range 20180218 to 20180223...
# Start Date: 20180218, End Date: 20180223
# Downloading data from refinitiv...
# (927, 74)
# Master shape: (8722, 74)
#      TR.MNASDCDealNumber TR.MNASDCDealNumber
# 0             2696976040          2696976040
# 1             2951155040          2951155040
# 2             3081061020          3081061020
# 3             3104001040          3104001040
# 4             3107974040          3107974040
# ...                  ...                 ...
# 8717          3597881040          3597881040
# 8718          3641523040          3641523040
# 8719          3656821020          3656821020
# 8720          3667938040          3667938040
# 8721          3688004020          3688004020
#
# [8722 rows x 2 columns]
# Start Date: 20180224, End Date: 20180301
# Downloading data from refinitiv...
# (1209, 74)
# Master shape: (9931, 74)
#      TR.MNASDCDealNumber TR.MNASDCDealNumber
# 0             2696976040          2696976040
# 1             2951155040          2951155040
# 2             3081061020          3081061020
# 3             3104001040          3104001040
# 4             3107974040          3107974040
# ...                  ...                 ...
# 9926          3651938020          3651938020
# 9927          3793872040          3793872040
# 9928          3914697020          3914697020
# 9929          4153914020          4153914020
# 9930          4233890040          4233890040
#
# [9931 rows x 2 columns]
# Start Date: 20180302, End Date: 20180307
# Downloading data from refinitiv...
# (828, 74)
# Master shape: (10759, 74)
#       TR.MNASDCDealNumber TR.MNASDCDealNumber
# 0              2696976040          2696976040
# 1              2951155040          2951155040
# 2              3081061020          3081061020
# 3              3104001040          3104001040
# 4              3107974040          3107974040
# ...                   ...                 ...
# 10754          3868926040          3868926040
# 10755          3983753020          3983753020
# 10756          4089445020          4089445020
# 10757          4217753020          4217753020
# 10758          4258386040          4258386040
#
# [10759 rows x 2 columns]
# Start Date: 20180308, End Date: 20180313
# Downloading data from refinitiv...
# (872, 74)
# Master shape: (11631, 74)
#       TR.MNASDCDealNumber TR.MNASDCDealNumber
# 0              2696976040          2696976040
# 1              2951155040          2951155040
# 2              3081061020          3081061020
# 3              3104001040          3104001040
# 4              3107974040          3107974040
# ...                   ...                 ...
# 11626          3627790020          3627790020
# 11627          3654910020          3654910020
# 11628          4055485040          4055485040
# 11629          4095170040          4095170040
# 11630          4128558040          4128558040
#
# [11631 rows x 2 columns]
# Start Date: 20180314, End Date: 20180319
# Downloading data from refinitiv...
# (896, 74)
# Master shape: (12527, 74)
#       TR.MNASDCDealNumber TR.MNASDCDealNumber
# 0              2696976040          2696976040
# 1              2951155040          2951155040
# 2              3081061020          3081061020
# 3              3104001040          3104001040
# 4              3107974040          3107974040
# ...                   ...                 ...
# 12522          4055399040          4055399040
# 12523          4142496040          4142496040
# 12524          4151683020          4151683020
# 12525          4165218020          4165218020
# 12526          4244255040          4244255040
#
# [12527 rows x 2 columns]
# Start Date: 20180320, End Date: 20180325
# Downloading data from refinitiv...
# (936, 74)
# Master shape: (13463, 74)
#       TR.MNASDCDealNumber TR.MNASDCDealNumber
# 0              2696976040          2696976040
# 1              2951155040          2951155040
# 2              3081061020          3081061020
# 3              3104001040          3104001040
# 4              3107974040          3107974040
# ...                   ...                 ...
# 13458          3919291040          3919291040
# 13459          4092559020          4092559020
# 13460          4122539020          4122539020
# 13461          4164715020          4164715020
# 13462          4188046020          4188046020
#
# [13463 rows x 2 columns]
# Start Date: 20180326, End Date: 20180331
# Downloading data from refinitiv...
# ERROR!!! An error occurred while requesting URL('https://api.refinitiv.com/data/datagrid/beta1/').
#      ReadTimeout('')
# An error occurred: . Retrying for the range 20180326 to 20180331...
# Start Date: 20180326, End Date: 20180331
# Downloading data from refinitiv...
# (1313, 74)
# Master shape: (14776, 74)
#       TR.MNASDCDealNumber TR.MNASDCDealNumber
# 0              2696976040          2696976040
# 1              2951155040          2951155040
# 2              3081061020          3081061020
# 3              3104001040          3104001040
# 4              3107974040          3107974040
# ...                   ...                 ...
# 14771          4158217020          4158217020
# 14772          4188533020          4188533020
# 14773          4189485040          4189485040
# 14774          4242710040          4242710040
# 14775          4270306040          4270306040
#
# [14776 rows x 2 columns]
# Start Date: 20180401, End Date: 20180406
# Downloading data from refinitiv...
# (1031, 74)
# Master shape: (15807, 74)
#       TR.MNASDCDealNumber TR.MNASDCDealNumber
# 0              2696976040          2696976040
# 1              2951155040          2951155040
# 2              3081061020          3081061020
# 3              3104001040          3104001040
# 4              3107974040          3107974040
# ...                   ...                 ...
# 15802          3622115020          3622115020
# 15803          3730864040          3730864040
# 15804          4095663040          4095663040
# 15805          4153350020          4153350020
# 15806          4249931040          4249931040
#
# [15807 rows x 2 columns]
# Start Date: 20180407, End Date: 20180412
# Downloading data from refinitiv...
# (823, 74)
# Master shape: (16630, 74)
#       TR.MNASDCDealNumber TR.MNASDCDealNumber
# 0              2696976040          2696976040
# 1              2951155040          2951155040
# 2              3081061020          3081061020
# 3              3104001040          3104001040
# 4              3107974040          3107974040
# ...                   ...                 ...
# 16625          3739809040          3739809040
# 16626          3739845040          3739845040
# 16627          4028794040          4028794040
# 16628          4122586020          4122586020
# 16629          4166611020          4166611020
#
# [16630 rows x 2 columns]
# Start Date: 20180413, End Date: 20180418
# Downloading data from refinitiv...
# (830, 74)
# Master shape: (17460, 74)
#       TR.MNASDCDealNumber TR.MNASDCDealNumber
# 0              2696976040          2696976040
# 1              2951155040          2951155040
# 2              3081061020          3081061020
# 3              3104001040          3104001040
# 4              3107974040          3107974040
# ...                   ...                 ...
# 17455          3847842040          3847842040
# 17456          4058223040          4058223040
# 17457          4068213020          4068213020
# 17458          4127633020          4127633020
# 17459          4235568040          4235568040
#
# [17460 rows x 2 columns]
# Start Date: 20180419, End Date: 20180424
# Downloading data from refinitiv...
# (853, 74)
# Master shape: (18313, 74)
#       TR.MNASDCDealNumber TR.MNASDCDealNumber
# 0              2696976040          2696976040
# 1              2951155040          2951155040
# 2              3081061020          3081061020
# 3              3104001040          3104001040
# 4              3107974040          3107974040
# ...                   ...                 ...
# 18308          3645967040          3645967040
# 18309          3699858040          3699858040
# 18310          3727142020          3727142020
# 18311          4122215020          4122215020
# 18312          4223453040          4223453040
#
# [18313 rows x 2 columns]
# Start Date: 20180425, End Date: 20180430
# Downloading data from refinitiv...
# (1002, 74)
# Master shape: (19315, 74)
#       TR.MNASDCDealNumber TR.MNASDCDealNumber
# 0              2696976040          2696976040
# 1              2951155040          2951155040
# 2              3081061020          3081061020
# 3              3104001040          3104001040
# 4              3107974040          3107974040
# ...                   ...                 ...
# 19310          4225230040          4225230040
# 19311          4225240040          4225240040
# 19312          4240517040          4240517040
# 19313          4266941040          4266941040
# 19314          4273192040          4273192040
#
# [19315 rows x 2 columns]
# Start Date: 20180501, End Date: 20180506
# Downloading data from refinitiv...
# (881, 74)
# Master shape: (20196, 74)
#       TR.MNASDCDealNumber TR.MNASDCDealNumber
# 0              2696976040          2696976040
# 1              2951155040          2951155040
# 2              3081061020          3081061020
# 3              3104001040          3104001040
# 4              3107974040          3107974040
# ...                   ...                 ...
# 20191          3761156040          3761156040
# 20192          3805353020          3805353020
# 20193          3920503040          3920503040
# 20194          4183324020          4183324020
# 20195          4242716040          4242716040
#
# [20196 rows x 2 columns]
# Start Date: 20180507, End Date: 20180512
# Downloading data from refinitiv...
# (984, 74)
# Master shape: (21180, 74)
#       TR.MNASDCDealNumber TR.MNASDCDealNumber
# 0              2696976040          2696976040
# 1              2951155040          2951155040
# 2              3081061020          3081061020
# 3              3104001040          3104001040
# 4              3107974040          3107974040
# ...                   ...                 ...
# 21175          4141347020          4141347020
# 21176          4147961020          4147961020
# 21177          4183240040          4183240040
# 21178          4262189040          4262189040
# 21179          4272221040          4272221040
#
# [21180 rows x 2 columns]
# Start Date: 20180513, End Date: 20180518
# Downloading data from refinitiv...
# (1083, 74)
# Master shape: (22263, 74)
#       TR.MNASDCDealNumber TR.MNASDCDealNumber
# 0              2696976040          2696976040
# 1              2951155040          2951155040
# 2              3081061020          3081061020
# 3              3104001040          3104001040
# 4              3107974040          3107974040
# ...                   ...                 ...
# 22258          4122189020          4122189020
# 22259          4122571020          4122571020
# 22260          4127623020          4127623020
# 22261          4162945040          4162945040
# 22262          4186971040          4186971040
#
# [22263 rows x 2 columns]
# Start Date: 20180519, End Date: 20180524
# Downloading data from refinitiv...
# (833, 74)
# Master shape: (23096, 74)
#       TR.MNASDCDealNumber TR.MNASDCDealNumber
# 0              2696976040          2696976040
# 1              2951155040          2951155040
# 2              3081061020          3081061020
# 3              3104001040          3104001040
# 4              3107974040          3107974040
# ...                   ...                 ...
# 23091          4045478040          4045478040
# 23092          4058227040          4058227040
# 23093          4162315020          4162315020
# 23094          4200100040          4200100040
# 23095          4204488020          4204488020
#
# [23096 rows x 2 columns]
# Start Date: 20180525, End Date: 20180530
# Downloading data from refinitiv...
# (763, 74)
# Master shape: (23859, 74)
#       TR.MNASDCDealNumber TR.MNASDCDealNumber
# 0              2696976040          2696976040
# 1              2951155040          2951155040
# 2              3081061020          3081061020
# 3              3104001040          3104001040
# 4              3107974040          3107974040
# ...                   ...                 ...
# 23854          4113903040          4113903040
# 23855          4165795020          4165795020
# 23856          4234536040          4234536040
# 23857          4261278040          4261278040
# 23858          4271241040          4271241040
#
# [23859 rows x 2 columns]
# Start Date: 20180531, End Date: 20180605
# Downloading data from refinitiv...
# (1030, 74)
# Master shape: (24889, 74)
#       TR.MNASDCDealNumber TR.MNASDCDealNumber
# 0              2696976040          2696976040
# 1              2951155040          2951155040
# 2              3081061020          3081061020
# 3              3104001040          3104001040
# 4              3107974040          3107974040
# ...                   ...                 ...
# 24884          4183665020          4183665020
# 24885          4188078020          4188078020
# 24886          4238668040          4238668040
# 24887          4257012040          4257012040
# 24888          4261900040          4261900040
#
# [24889 rows x 2 columns]
# Start Date: 20180606, End Date: 20180611
# Downloading data from refinitiv...
# (842, 74)
# Master shape: (25731, 74)
#       TR.MNASDCDealNumber TR.MNASDCDealNumber
# 0              2696976040          2696976040
# 1              2951155040          2951155040
# 2              3081061020          3081061020
# 3              3104001040          3104001040
# 4              3107974040          3107974040
# ...                   ...                 ...
# 25726          3513186040          3513186040
# 25727          3604334040          3604334040
# 25728          4025464040          4025464040
# 25729          4152843020          4152843020
# 25730          4241618040          4241618040
#
# [25731 rows x 2 columns]
# Start Date: 20180612, End Date: 20180617
# Downloading data from refinitiv...
# (836, 74)
# Master shape: (26567, 74)
#       TR.MNASDCDealNumber TR.MNASDCDealNumber
# 0              2696976040          2696976040
# 1              2951155040          2951155040
# 2              3081061020          3081061020
# 3              3104001040          3104001040
# 4              3107974040          3107974040
# ...                   ...                 ...
# 26562          3649014020          3649014020
# 26563          3656669020          3656669020
# 26564          4055402040          4055402040
# 26565          4062987040          4062987040
# 26566          4100196040          4100196040
#
# [26567 rows x 2 columns]
# Start Date: 20180618, End Date: 20180623
# Downloading data from refinitiv...
# (1030, 74)
# Master shape: (27597, 74)
#       TR.MNASDCDealNumber TR.MNASDCDealNumber
# 0              2696976040          2696976040
# 1              2951155040          2951155040
# 2              3081061020          3081061020
# 3              3104001040          3104001040
# 4              3107974040          3107974040
# ...                   ...                 ...
# 27592          3707488040          3707488040
# 27593          3971176020          3971176020
# 27594          4065713040          4065713040
# 27595          4170571020          4170571020
# 27596          4188551020          4188551020
#
# [27597 rows x 2 columns]
# Start Date: 20180624, End Date: 20180629
# Downloading data from refinitiv...
# (1248, 74)
# Master shape: (28845, 74)
#       TR.MNASDCDealNumber TR.MNASDCDealNumber
# 0              2696976040          2696976040
# 1              2951155040          2951155040
# 2              3081061020          3081061020
# 3              3104001040          3104001040
# 4              3107974040          3107974040
# ...                   ...                 ...
# 28840          3817642040          3817642040
# 28841          4058230040          4058230040
# 28842          4071363040          4071363040
# 28843          4123675040          4123675040
# 28844          4254351020          4254351020
#
# [28845 rows x 2 columns]
# Start Date: 20180630, End Date: 20180705
# Downloading data from refinitiv...
# (1062, 74)
# Master shape: (29907, 74)
#       TR.MNASDCDealNumber TR.MNASDCDealNumber
# 0              2696976040          2696976040
# 1              2951155040          2951155040
# 2              3081061020          3081061020
# 3              3104001040          3104001040
# 4              3107974040          3107974040
# ...                   ...                 ...
# 29902          4164015020          4164015020
# 29903          4182799040          4182799040
# 29904          4213452020          4213452020
# 29905          4237973040          4237973040
# 29906          4270768040          4270768040
#
# [29907 rows x 2 columns]
# Start Date: 20180706, End Date: 20180711
# Downloading data from refinitiv...
# ERROR!!! An error occurred while requesting URL('https://api.refinitiv.com/data/datagrid/beta1/').
#      ReadTimeout('')
# An error occurred: . Retrying for the range 20180706 to 20180711...
# Start Date: 20180706, End Date: 20180711
# Downloading data from refinitiv...
# (818, 74)
# Master shape: (30725, 74)
#       TR.MNASDCDealNumber TR.MNASDCDealNumber
# 0              2696976040          2696976040
# 1              2951155040          2951155040
# 2              3081061020          3081061020
# 3              3104001040          3104001040
# 4              3107974040          3107974040
# ...                   ...                 ...
# 30720          4055486040          4055486040
# 30721          4183319040          4183319040
# 30722          4223910040          4223910040
# 30723          4238667040          4238667040
# 30724          4258948040          4258948040
#
# [30725 rows x 2 columns]
# Start Date: 20180712, End Date: 20180717
# Downloading data from refinitiv...
# ERROR!!! An error occurred while requesting URL('https://api.refinitiv.com/data/datagrid/beta1/').
#      ReadTimeout('')
# An error occurred: . Retrying for the range 20180712 to 20180717...
# Start Date: 20180712, End Date: 20180717
# Downloading data from refinitiv...
# (823, 74)
# Master shape: (31548, 74)
#       TR.MNASDCDealNumber TR.MNASDCDealNumber
# 0              2696976040          2696976040
# 1              2951155040          2951155040
# 2              3081061020          3081061020
# 3              3104001040          3104001040
# 4              3107974040          3107974040
# ...                   ...                 ...
# 31543          4123700020          4123700020
# 31544          4147984020          4147984020
# 31545          4166602020          4166602020
# 31546          4257037040          4257037040
# 31547          4267238040          4267238040
#
# [31548 rows x 2 columns]
# Start Date: 20180718, End Date: 20180723
# Downloading data from refinitiv...
# (773, 74)
# Master shape: (32321, 74)
#       TR.MNASDCDealNumber TR.MNASDCDealNumber
# 0              2696976040          2696976040
# 1              2951155040          2951155040
# 2              3081061020          3081061020
# 3              3104001040          3104001040
# 4              3107974040          3107974040
# ...                   ...                 ...
# 32316          3603852040          3603852040
# 32317          3684958040          3684958040
# 32318          3792083020          3792083020
# 32319          4162409040          4162409040
# 32320          4249966040          4249966040
#
# [32321 rows x 2 columns]
# Start Date: 20180724, End Date: 20180729
# Downloading data from refinitiv...
# (833, 74)
# Master shape: (33154, 74)
#       TR.MNASDCDealNumber TR.MNASDCDealNumber
# 0              2696976040          2696976040
# 1              2951155040          2951155040
# 2              3081061020          3081061020
# 3              3104001040          3104001040
# 4              3107974040          3107974040
# ...                   ...                 ...
# 33149          4046702020          4046702020
# 33150          4061698040          4061698040
# 33151          4104007020          4104007020
# 33152          4241007040          4241007040
# 33153          4260424040          4260424040
#
# [33154 rows x 2 columns]
# Start Date: 20180730, End Date: 20180804
# Downloading data from refinitiv...
# (1297, 74)
# Master shape: (34451, 74)
#       TR.MNASDCDealNumber TR.MNASDCDealNumber
# 0              2696976040          2696976040
# 1              2951155040          2951155040
# 2              3081061020          3081061020
# 3              3104001040          3104001040
# 4              3107974040          3107974040
# ...                   ...                 ...
# 34446          4095091040          4095091040
# 34447          4095828040          4095828040
# 34448          4151254040          4151254040
# 34449          4237183040          4237183040
# 34450          4258824040          4258824040
#
# [34451 rows x 2 columns]
# Start Date: 20180805, End Date: 20180810
# Downloading data from refinitiv...
# (931, 74)
# Master shape: (35382, 74)
#       TR.MNASDCDealNumber TR.MNASDCDealNumber
# 0              2696976040          2696976040
# 1              2951155040          2951155040
# 2              3081061020          3081061020
# 3              3104001040          3104001040
# 4              3107974040          3107974040
# ...                   ...                 ...
# 35377          4079619040          4079619040
# 35378          4110952020          4110952020
# 35379          4122977020          4122977020
# 35380          4249191020          4249191020
# 35381          4258548040          4258548040
#
# [35382 rows x 2 columns]
# Start Date: 20180811, End Date: 20180816
# Downloading data from refinitiv...
# ERROR!!! An error occurred while requesting URL('https://api.refinitiv.com/data/datagrid/beta1/').
#      ReadTimeout('')
# An error occurred: . Retrying for the range 20180811 to 20180816...
# Start Date: 20180811, End Date: 20180816
# Downloading data from refinitiv...
# ERROR!!! An error occurred while requesting URL('https://api.refinitiv.com/data/datagrid/beta1/').
#      ReadTimeout('')
# An error occurred: . Retrying for the range 20180811 to 20180816...
# Start Date: 20180811, End Date: 20180816
# Downloading data from refinitiv...
# (739, 74)
# Master shape: (36121, 74)
#       TR.MNASDCDealNumber TR.MNASDCDealNumber
# 0              2696976040          2696976040
# 1              2951155040          2951155040
# 2              3081061020          3081061020
# 3              3104001040          3104001040
# 4              3107974040          3107974040
# ...                   ...                 ...
# 36116          4057005040          4057005040
# 36117          4069696040          4069696040
# 36118          4103993020          4103993020
# 36119          4188003040          4188003040
# 36120          4240595040          4240595040
#
# [36121 rows x 2 columns]
# Start Date: 20180817, End Date: 20180822
# Downloading data from refinitiv...
# (704, 74)
# Master shape: (36825, 74)
#       TR.MNASDCDealNumber TR.MNASDCDealNumber
# 0              2696976040          2696976040
# 1              2951155040          2951155040
# 2              3081061020          3081061020
# 3              3104001040          3104001040
# 4              3107974040          3107974040
# ...                   ...                 ...
# 36820          4085952040          4085952040
# 36821          4108579020          4108579020
# 36822          4160321020          4160321020
# 36823          4163124040          4163124040
# 36824          4217751020          4217751020
#
# [36825 rows x 2 columns]
# Start Date: 20180823, End Date: 20180828
# Downloading data from refinitiv...
# (743, 74)
# Master shape: (37568, 74)
#       TR.MNASDCDealNumber TR.MNASDCDealNumber
# 0              2696976040          2696976040
# 1              2951155040          2951155040
# 2              3081061020          3081061020
# 3              3104001040          3104001040
# 4              3107974040          3107974040
# ...                   ...                 ...
# 37563          4114467020          4114467020
# 37564          4120941020          4120941020
# 37565          4143367020          4143367020
# 37566          4238679040          4238679040
# 37567          4269439040          4269439040
#
# [37568 rows x 2 columns]
# Start Date: 20180829, End Date: 20180903
# Downloading data from refinitiv...
# ERROR!!! An error occurred while requesting URL('https://api.refinitiv.com/data/datagrid/beta1/').
#      ReadTimeout('')
# An error occurred: . Retrying for the range 20180829 to 20180903...
# Start Date: 20180829, End Date: 20180903
# Downloading data from refinitiv...
# (879, 74)
# Master shape: (38447, 74)
#       TR.MNASDCDealNumber TR.MNASDCDealNumber
# 0              2696976040          2696976040
# 1              2951155040          2951155040
# 2              3081061020          3081061020
# 3              3104001040          3104001040
# 4              3107974040          3107974040
# ...                   ...                 ...
# 38442          3733752040          3733752040
# 38443          4124443020          4124443020
# 38444          4126642020          4126642020
# 38445          4128373040          4128373040
# 38446          4267486040          4267486040
#
# [38447 rows x 2 columns]
# Start Date: 20180904, End Date: 20180909
# Downloading data from refinitiv...
# ERROR!!! An error occurred while requesting URL('https://api.refinitiv.com/data/datagrid/beta1/').
#      ReadTimeout('')
# An error occurred: . Retrying for the range 20180904 to 20180909...
# Start Date: 20180904, End Date: 20180909
# Downloading data from refinitiv...
# ERROR!!! An error occurred while requesting URL('https://api.refinitiv.com/data/datagrid/beta1/').
#      ReadTimeout('')
# An error occurred: . Retrying for the range 20180904 to 20180909...
# Start Date: 20180904, End Date: 20180909
# Downloading data from refinitiv...
# ERROR!!! An error occurred while requesting URL('https://api.refinitiv.com/data/datagrid/beta1/').
#      ReadTimeout('')
# An error occurred: . Retrying for the range 20180904 to 20180909...
# Start Date: 20180904, End Date: 20180909
# Downloading data from refinitiv...
# ERROR!!! An error occurred while requesting URL('https://api.refinitiv.com/data/datagrid/beta1/').
#      ReadTimeout('')
# An error occurred: . Retrying for the range 20180904 to 20180909...
# Start Date: 20180904, End Date: 20180909
# Downloading data from refinitiv...
# (878, 74)
# Master shape: (39325, 74)
#       TR.MNASDCDealNumber TR.MNASDCDealNumber
# 0              2696976040          2696976040
# 1              2951155040          2951155040
# 2              3081061020          3081061020
# 3              3104001040          3104001040
# 4              3107974040          3107974040
# ...                   ...                 ...
# 39320          4092518020          4092518020
# 39321          4122676020          4122676020
# 39322          4164759040          4164759040
# 39323          4242719040          4242719040
# 39324          4256985040          4256985040
#
# [39325 rows x 2 columns]
# Start Date: 20180910, End Date: 20180915
# Downloading data from refinitiv...
# (996, 74)
# Master shape: (40321, 74)
#       TR.MNASDCDealNumber TR.MNASDCDealNumber
# 0              2696976040          2696976040
# 1              2951155040          2951155040
# 2              3081061020          3081061020
# 3              3104001040          3104001040
# 4              3107974040          3107974040
# ...                   ...                 ...
# 40316          3651952020          3651952020
# 40317          4095197040          4095197040
# 40318          4143830020          4143830020
# 40319          4153439020          4153439020
# 40320          4189080040          4189080040
#
# [40321 rows x 2 columns]
# Start Date: 20180916, End Date: 20180921
# Downloading data from refinitiv...
# (1017, 74)
# Master shape: (41338, 74)
#       TR.MNASDCDealNumber TR.MNASDCDealNumber
# 0              2696976040          2696976040
# 1              2951155040          2951155040
# 2              3081061020          3081061020
# 3              3104001040          3104001040
# 4              3107974040          3107974040
# ...                   ...                 ...
# 41333          4122959020          4122959020
# 41334          4129315020          4129315020
# 41335          4164035020          4164035020
# 41336          4183642020          4183642020
# 41337          4260395040          4260395040
#
# [41338 rows x 2 columns]
# Start Date: 20180922, End Date: 20180927
# Downloading data from refinitiv...
# (864, 74)
# Master shape: (42202, 74)
#       TR.MNASDCDealNumber TR.MNASDCDealNumber
# 0              2696976040          2696976040
# 1              2951155040          2951155040
# 2              3081061020          3081061020
# 3              3104001040          3104001040
# 4              3107974040          3107974040
# ...                   ...                 ...
# 42197          4112276020          4112276020
# 42198          4135122040          4135122040
# 42199          4155006020          4155006020
# 42200          4194339040          4194339040
# 42201          4210450040          4210450040
#
# [42202 rows x 2 columns]
# Start Date: 20180928, End Date: 20181003
# Downloading data from refinitiv...
# (1150, 74)
# Master shape: (43352, 74)
#       TR.MNASDCDealNumber TR.MNASDCDealNumber
# 0              2696976040          2696976040
# 1              2951155040          2951155040
# 2              3081061020          3081061020
# 3              3104001040          3104001040
# 4              3107974040          3107974040
# ...                   ...                 ...
# 43347          3637066020          3637066020
# 43348          3885905040          3885905040
# 43349          4145847020          4145847020
# 43350          4162310040          4162310040
# 43351          4164120020          4164120020
#
# [43352 rows x 2 columns]
# Start Date: 20181004, End Date: 20181009
# Downloading data from refinitiv...
# (709, 74)
# Master shape: (44061, 74)
#       TR.MNASDCDealNumber TR.MNASDCDealNumber
# 0              2696976040          2696976040
# 1              2951155040          2951155040
# 2              3081061020          3081061020
# 3              3104001040          3104001040
# 4              3107974040          3107974040
# ...                   ...                 ...
# 44056          3622750020          3622750020
# 44057          3832709040          3832709040
# 44058          4055491040          4055491040
# 44059          4095183040          4095183040
# 44060          4139337020          4139337020
#
# [44061 rows x 2 columns]
# Start Date: 20181010, End Date: 20181015
# Downloading data from refinitiv...
# (826, 74)
# Master shape: (44887, 74)
#       TR.MNASDCDealNumber TR.MNASDCDealNumber
# 0              2696976040          2696976040
# 1              2951155040          2951155040
# 2              3081061020          3081061020
# 3              3104001040          3104001040
# 4              3107974040          3107974040
# ...                   ...                 ...
# 44882          3654903020          3654903020
# 44883          3656810020          3656810020
# 44884          3900631040          3900631040
# 44885          3991477020          3991477020
# 44886          4021456020          4021456020
#
# [44887 rows x 2 columns]
# Start Date: 20181016, End Date: 20181021
# Downloading data from refinitiv...
# (854, 74)
# Master shape: (45741, 74)
#       TR.MNASDCDealNumber TR.MNASDCDealNumber
# 0              2696976040          2696976040
# 1              2951155040          2951155040
# 2              3081061020          3081061020
# 3              3104001040          3104001040
# 4              3107974040          3107974040
# ...                   ...                 ...
# 45736          3600135040          3600135040
# 45737          3601556020          3601556020
# 45738          4037772020          4037772020
# 45739          4037778020          4037778020
# 45740          4164075040          4164075040
#
# [45741 rows x 2 columns]
# Start Date: 20181022, End Date: 20181027
# Downloading data from refinitiv...
# (1037, 74)
# Master shape: (46778, 74)
#       TR.MNASDCDealNumber TR.MNASDCDealNumber
# 0              2696976040          2696976040
# 1              2951155040          2951155040
# 2              3081061020          3081061020
# 3              3104001040          3104001040
# 4              3107974040          3107974040
# ...                   ...                 ...
# 46773          4125804040          4125804040
# 46774          4164694020          4164694020
# 46775          4165791020          4165791020
# 46776          4214808040          4214808040
# 46777          4239271040          4239271040
#
# [46778 rows x 2 columns]
# Start Date: 20181028, End Date: 20181102
# Downloading data from refinitiv...
# ERROR!!! An error occurred while requesting URL('https://api.refinitiv.com/data/datagrid/beta1/').
#      ReadTimeout('')
# An error occurred: . Retrying for the range 20181028 to 20181102...
# Start Date: 20181028, End Date: 20181102
# Downloading data from refinitiv...
# ERROR!!! An error occurred while requesting URL('https://api.refinitiv.com/data/datagrid/beta1/').
#      ReadTimeout('')
# An error occurred: . Retrying for the range 20181028 to 20181102...
# Start Date: 20181028, End Date: 20181102
# Downloading data from refinitiv...
# (1267, 74)
# Master shape: (48045, 74)
#       TR.MNASDCDealNumber TR.MNASDCDealNumber
# 0              2696976040          2696976040
# 1              2951155040          2951155040
# 2              3081061020          3081061020
# 3              3104001040          3104001040
# 4              3107974040          3107974040
# ...                   ...                 ...
# 48040          4104598020          4104598020
# 48041          4154586020          4154586020
# 48042          4168739040          4168739040
# 48043          4195815040          4195815040
# 48044          4251383040          4251383040
#
# [48045 rows x 2 columns]
# Start Date: 20181103, End Date: 20181108
# Downloading data from refinitiv...
# ERROR!!! An error occurred while requesting URL('https://api.refinitiv.com/data/datagrid/beta1/').
#      ReadTimeout('')
# An error occurred: . Retrying for the range 20181103 to 20181108...
# Start Date: 20181103, End Date: 20181108
# Downloading data from refinitiv...
# ERROR!!! An error occurred while requesting URL('https://api.refinitiv.com/data/datagrid/beta1/').
#      ReadTimeout('')
# An error occurred: . Retrying for the range 20181103 to 20181108...
# Start Date: 20181103, End Date: 20181108
# Downloading data from refinitiv...
# (894, 74)
# Master shape: (48939, 74)
#       TR.MNASDCDealNumber TR.MNASDCDealNumber
# 0              2696976040          2696976040
# 1              2951155040          2951155040
# 2              3081061020          3081061020
# 3              3104001040          3104001040
# 4              3107974040          3107974040
# ...                   ...                 ...
# 48934          3630794020          3630794020
# 48935          3644505020          3644505020
# 48936          4130677040          4130677040
# 48937          4182519040          4182519040
# 48938          4265753040          4265753040
#
# [48939 rows x 2 columns]
# Start Date: 20181109, End Date: 20181114
# Downloading data from refinitiv...
# (817, 74)
# Master shape: (49756, 74)
#       TR.MNASDCDealNumber TR.MNASDCDealNumber
# 0              2696976040          2696976040
# 1              2951155040          2951155040
# 2              3081061020          3081061020
# 3              3104001040          3104001040
# 4              3107974040          3107974040
# ...                   ...                 ...
# 49751          4143258040          4143258040
# 49752          4143678020          4143678020
# 49753          4186848020          4186848020
# 49754          4235569040          4235569040
# 49755          4261452040          4261452040
#
# [49756 rows x 2 columns]
# Start Date: 20181115, End Date: 20181120
# Downloading data from refinitiv...
# ERROR!!! An error occurred while requesting URL('https://api.refinitiv.com/data/datagrid/beta1/').
#      ReadTimeout('')
# An error occurred: . Retrying for the range 20181115 to 20181120...
# Start Date: 20181115, End Date: 20181120
# Downloading data from refinitiv...
# (777, 74)
# Master shape: (50533, 74)
#       TR.MNASDCDealNumber TR.MNASDCDealNumber
# 0              2696976040          2696976040
# 1              2951155040          2951155040
# 2              3081061020          3081061020
# 3              3104001040          3104001040
# 4              3107974040          3107974040
# ...                   ...                 ...
# 50528          3738701020          3738701020
# 50529          3986644040          3986644040
# 50530          3990043020          3990043020
# 50531          4127108040          4127108040
# 50532          4237356020          4237356020
#
# [50533 rows x 2 columns]
# Start Date: 20181121, End Date: 20181126
# Downloading data from refinitiv...
# (695, 74)
# Master shape: (51228, 74)
#       TR.MNASDCDealNumber TR.MNASDCDealNumber
# 0              2696976040          2696976040
# 1              2951155040          2951155040
# 2              3081061020          3081061020
# 3              3104001040          3104001040
# 4              3107974040          3107974040
# ...                   ...                 ...
# 51223          3920516040          3920516040
# 51224          4104018020          4104018020
# 51225          4151691020          4151691020
# 51226          4222882040          4222882040
# 51227          4258411040          4258411040
#
# [51228 rows x 2 columns]
# Start Date: 20181127, End Date: 20181202
# Downloading data from refinitiv...
# (988, 74)
# Master shape: (52216, 74)
#       TR.MNASDCDealNumber TR.MNASDCDealNumber
# 0              2696976040          2696976040
# 1              2951155040          2951155040
# 2              3081061020          3081061020
# 3              3104001040          3104001040
# 4              3107974040          3107974040
# ...                   ...                 ...
# 52211          4056911040          4056911040
# 52212          4115720040          4115720040
# 52213          4188094020          4188094020
# 52214          4238666040          4238666040
# 52215          4238681040          4238681040
#
# [52216 rows x 2 columns]
# Start Date: 20181203, End Date: 20181208
# Downloading data from refinitiv...
# (1070, 74)
# Master shape: (53286, 74)
#       TR.MNASDCDealNumber TR.MNASDCDealNumber
# 0              2696976040          2696976040
# 1              2951155040          2951155040
# 2              3081061020          3081061020
# 3              3104001040          3104001040
# 4              3107974040          3107974040
# ...                   ...                 ...
# 53281          3769120020          3769120020
# 53282          4049396020          4049396020
# 53283          4055500040          4055500040
# 53284          4199419040          4199419040
# 53285          4272251040          4272251040
#
# [53286 rows x 2 columns]
# Start Date: 20181209, End Date: 20181214
# Downloading data from refinitiv...
# ERROR!!! An error occurred while requesting URL('https://api.refinitiv.com/data/datagrid/beta1/').
#      ReadTimeout('')
# An error occurred: . Retrying for the range 20181209 to 20181214...
# Start Date: 20181209, End Date: 20181214
# Downloading data from refinitiv...
# (1079, 74)
# Master shape: (54365, 74)
#       TR.MNASDCDealNumber TR.MNASDCDealNumber
# 0              2696976040          2696976040
# 1              2951155040          2951155040
# 2              3081061020          3081061020
# 3              3104001040          3104001040
# 4              3107974040          3107974040
# ...                   ...                 ...
# 54360          4095762040          4095762040
# 54361          4111876020          4111876020
# 54362          4156788020          4156788020
# 54363          4200810020          4200810020
# 54364          4217747020          4217747020
#
# [54365 rows x 2 columns]
# Start Date: 20181215, End Date: 20181220
# Downloading data from refinitiv...
# (1175, 74)
# Master shape: (55540, 74)
#       TR.MNASDCDealNumber TR.MNASDCDealNumber
# 0              2696976040          2696976040
# 1              2951155040          2951155040
# 2              3081061020          3081061020
# 3              3104001040          3104001040
# 4              3107974040          3107974040
# ...                   ...                 ...
# 55535          4187061040          4187061040
# 55536          4254279040          4254279040
# 55537          4261038040          4261038040
# 55538          4261099040          4261099040
# 55539          4265229040          4265229040
#
# [55540 rows x 2 columns]
# Start Date: 20181221, End Date: 20181226
# Downloading data from refinitiv...
# (636, 74)
# Master shape: (56176, 74)
#       TR.MNASDCDealNumber TR.MNASDCDealNumber
# 0              2696976040          2696976040
# 1              2951155040          2951155040
# 2              3081061020          3081061020
# 3              3104001040          3104001040
# 4              3107974040          3107974040
# ...                   ...                 ...
# 56171          3857617040          3857617040
# 56172          3990031020          3990031020
# 56173          4185942040          4185942040
# 56174          4264681040          4264681040
# 56175          4265307040          4265307040
#
# [56176 rows x 2 columns]
# Start Date: 20181227, End Date: 20190101
# Downloading data from refinitiv...
# ERROR!!! An error occurred while requesting URL('https://api.refinitiv.com/data/datagrid/beta1/').
#      ReadTimeout('')
# An error occurred: . Retrying for the range 20181227 to 20190101...
# Start Date: 20181227, End Date: 20190101
# Downloading data from refinitiv...
# (759, 74)
# Master shape: (56935, 74)
#       TR.MNASDCDealNumber TR.MNASDCDealNumber
# 0              2696976040          2696976040
# 1              2951155040          2951155040
# 2              3081061020          3081061020
# 3              3104001040          3104001040
# 4              3107974040          3107974040
# ...                   ...                 ...
# 56930          4177297040          4177297040
# 56931          4242721040          4242721040
# 56932          4261800040          4261800040
# 56933          4267565040          4267565040
# 56934          4270805040          4270805040
#
# [56935 rows x 2 columns]
# Start Date: 20190102, End Date: 20190107
# Downloading data from refinitiv...
# (662, 74)
# Master shape: (57597, 74)
#       TR.MNASDCDealNumber TR.MNASDCDealNumber
# 0              2696976040          2696976040
# 1              2951155040          2951155040
# 2              3081061020          3081061020
# 3              3104001040          3104001040
# 4              3107974040          3107974040
# ...                   ...                 ...
# 57592          4086421040          4086421040
# 57593          4140879020          4140879020
# 57594          4148125020          4148125020
# 57595          4158850020          4158850020
# 57596          4186266020          4186266020
#
# [57597 rows x 2 columns]
# Start Date: 20190108, End Date: 20190113
# Downloading data from refinitiv...
# (787, 74)
# Master shape: (58384, 74)
#       TR.MNASDCDealNumber TR.MNASDCDealNumber
# 0              2696976040          2696976040
# 1              2951155040          2951155040
# 2              3081061020          3081061020
# 3              3104001040          3104001040
# 4              3107974040          3107974040
# ...                   ...                 ...
# 58379          3955160040          3955160040
# 58380          4087420020          4087420020
# 58381          4099143020          4099143020
# 58382          4129515020          4129515020
# 58383          4160952020          4160952020
#
# [58384 rows x 2 columns]
# Start Date: 20190114, End Date: 20190119
# Downloading data from refinitiv...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[29], line 54
#      48             mna_screen = f'SCREEN(U(IN(DEALS)/*UNV:DEALSMNA*/),\
#      49                         BETWEEN(TR.MnAAnnDate,{start},{end})/*dt:Date*/, \
#      50                         CURN=USD)'
#      53             # input ipo screen results as instrument list and pull ipo attributes via fields from Eikon Data API.
# ---> 54             mnas = rdp.get_data(mna_screen,['TR.MNASDCDealNumber',
#      55                                             'TR.MnAAnnDate', 'TR.MnARankValueIncNetDebt(Curn=USD,Scale=6)',
#      56                                             'TR.MnATarget', 'TR.MnATargetPermId',
#      57                                             'TR.MnATargetPriTickerSym',
#      58                                             'TR.MnATargetNation',
#      59                                             'TR.MnATargetMacroInd',
#      60                                             'TR.MnATargetMidInd',
#      61                                             'TR.MnAAcquiror',
#      62                                             'TR.MnAAcquirorPermId',
#      63                                             'TR.MnAAcquirorMacroInd',
#      64                                             'TR.MnAAcquirorMidInd',
#      65                                             'TR.MnAAcquirorNation',
#      66                                             'TR.MNASDCDealNumber',
#      67                                             'TR.MNADealId','TR.MnASynopsis',
#      68                                             'TR.MnAAcquirorPermId',
#      69                                             'TR.MnAAcquirorPriHiTech',
#      70                                             'TR.MnAAcquirorPriTickerSym',
#      71                                             'TR.MnAAcquirorExchTicker(Concat="|")',
#      72                                             'TR.MnAAcquirorUltParentPermID',
#      73                                             'TR.MnAHiTechGroup(Concat="|")',
#      74                                             'TR.MnaAcquirorDate1DayPriorToAnn',
#      75                                             'TR.MnaAcquirorStockPrice1DayPriorToAnnInAcqCurr',
#      76                                             'TR.MnAAcquirorStockPriceOnAnn(Curn=USD)',
#      77                                             'TR.MnAAcquirorStockPrice1DayPostAnn(Curn=USD)',
#      78                                             'TR.MnASnP5001DayPreAnn',
#      79                                             'TR.MnASnP500AtAnnouncement',
#      80                                             'TR.MnASnP5001DayPostAnn',
#      81                                             'TR.MnATargetSDCCusip',
#      82                                             'TR.MnAAcquirorSDCCusip',
#      83                                             'TR.MnAAcquirorUltParentSDCCusip',
#      84                                             'TR.MnAValueOfCash(Curn=USD, Scale=6)',
#      85                                             'TR.MnAValueOfEarnout(Curn=USD, Scale=6)',
#      86                                             'TR.MnADealValue(Curn=USD, Scale=6)',
#      87                                             'TR.MnAAcquirorHiTech(Concat="|")',
#      88                                             'TR.MnAAcquirorUltParentHiTech(Concat="|")',
#      89                                             'TR.MnATargetPriHiTech',
#      90                                             'TR.MnAAcquirorMajorInd',
#      91                                             'TR.MnAAcquirorMajorIndGrp',
#      92                                             'TR.MnAAcquirorPriVEIC',
#      93                                             'TR.MnAMasterDealType',
#      94                                             'TR.MnADealType',
#      95                                             'TR.MnAType(Concat="|")',
#      96                                             'TR.MnAAcquirorVeic(Concat="|")',
#      97                                             'TR.MnAPurposeDescription',
#      98                                             'TR.MnAIsCrossBorder',
#      99                                             'TR.MnAAcquirorIsVentureFirm',
#     100                                             'TR.MnATargetPriVEIC',
#     101                                             'TR.MnATargetVeic(Concat="|")',
#     102                                             'TR.MnAAcquirorBusDesc',
#     103                                             'TR.MnATargetBusDesc',
#     104                                             'TR.MnATargetPermId',
#     105                                             'TR.MnATargetExchTicker(Concat="|")',
#     106                                             'TR.MnATargetUltParentSDCCusip',
#     107                                             'TR.MnATargetUltParentPriTickerSym',
#     108                                             'TR.MnATargetUltParentPermID',
#     109                                             'TR.MnAAcquirorUltParentPriTickerSym',
#     110                                             'TR.MnAAcquirorUltParentExchTicker(Concat="|")',
#     111                                             'TR.MnATargetUltParentExchTicker(Concat="|")',
#     112                                             'TR.MnATargetMajorInd',
#     113                                             'TR.MnATargetMajorIndGrp',
#     114                                             'TR.MnATargetHiTech(Concat="|")',
#     115                                             'TR.MnAAcquirorUltParentPriHiTech',
#     116                                             'TR.MnAAcquirorHiTechGroup(Concat="|")',
#     117                                             'TR.MnATargetHiTechGroup(Concat="|")',
#     118                                             'TR.MnAWithdrawnDate',
#     119                                             'TR.MnADateUnconditional',
#     120                                             'TR.MnAOrigAnnDate',
#     121                                             'TR.MnAPercentCash',
#     122                                             'TR.MnADealCurrency',
#     123                                             'TR.MnAEarnoutDesc'])
#     125             print(mnas.shape)
#     127 #             print("Uploading data to BQ...")
#     128 #             mnas.columns = [col[3:].lower() for col in mnas.columns]
#     129
#    (...)
#     135
#     136 #             print("Data appended successfully.")
#
# File /opt/conda/lib/python3.10/site-packages/refinitiv/dataplatform/content/data_grid/_functions.py:80, in get_data(universe, fields, parameters, field_name)
#       9 def get_data(
#      10     universe,
#      11     fields,
#      12     parameters=None,
#      13     field_name=None,
#      14 ):
#      15     """
#      16     Returns a pandas.DataFrame with fields in columns and instruments as row index
#      17
#    (...)
#      77     >>> data = rdp.get_data(["IBM","MSFT.O"], fields)
#      78     """
# ---> 80     result = Fundamental.get_data(
#      81         universe=universe,
#      82         fields=fields,
#      83         parameters=parameters,
#      84         field_name=field_name,
#      85     )
#      86     from refinitiv.dataplatform.factory.content_factory import ContentFactory
#      88     if result.is_success and result.data and result.data.df is not None:
#
# File /opt/conda/lib/python3.10/site-packages/refinitiv/dataplatform/content/data_grid/_fundamental_class.py:67, in Fundamental.get_data(universe, fields, parameters, field_name, on_response, closure, session)
#      56 @staticmethod
#      57 def get_data(
#      58     universe,
#    (...)
#      64     session=None,
#      65 ):
#      66     fundamental = Fundamental(session=session, on_response=on_response)
# ---> 67     result = fundamental._get_data(
#      68         universe=universe,
#      69         fields=fields,
#      70         parameters=parameters,
#      71         field_name=field_name,
#      72         closure=None,
#      73         session=None,
#      74     )
#      75     return result
#
# File /opt/conda/lib/python3.10/site-packages/refinitiv/dataplatform/content/data_grid/_fundamental_class.py:94, in Fundamental._get_data(self, universe, fields, parameters, field_name, closure, session)
#      77 def _get_data(
#      78     self,
#      79     universe,
#    (...)
#      84     session=None,
#      85 ):
#      86     """
#      87     :param universe: list    The list of RICs
#      88     :param fields: list      List of fundamental field names
#    (...)
#      92     :return:Response
#      93     """
# ---> 94     result = self._run_until_complete(
#      95         self._get_data_async(
#      96             universe=universe,
#      97             fields=fields,
#      98             parameters=parameters,
#      99             field_name=field_name,
#     100             closure=closure,
#     101         )
#     102     )
#     103     return result
#
# File /opt/conda/lib/python3.10/site-packages/refinitiv/dataplatform/content/data_grid/_fundamental_class.py:54, in Fundamental._run_until_complete(self, future)
#      53 def _run_until_complete(self, future):
# ---> 54     return self._endpoint.session._loop.run_until_complete(future)
#
# File /opt/conda/lib/python3.10/site-packages/nest_asyncio.py:92, in _patch_loop.<locals>.run_until_complete(self, future)
#      90     f._log_destroy_pending = False
#      91 while not f.done():
# ---> 92     self._run_once()
#      93     if self._stopping:
#      94         break
#
# File /opt/conda/lib/python3.10/site-packages/nest_asyncio.py:115, in _patch_loop.<locals>._run_once(self)
#     108     heappop(scheduled)
#     110 timeout = (
#     111     0 if ready or self._stopping
#     112     else min(max(
#     113         scheduled[0]._when - self.time(), 0), 86400) if scheduled
#     114     else None)
# --> 115 event_list = self._selector.select(timeout)
#     116 self._process_events(event_list)
#     118 end_time = self.time() + self._clock_resolution
#
# File /opt/conda/lib/python3.10/selectors.py:469, in EpollSelector.select(self, timeout)
#     467 ready = []
#     468 try:
# --> 469     fd_event_list = self._selector.poll(timeout, max_ev)
#     470 except InterruptedError:
#     471     return ready
#
# KeyboardInterrupt:
# ERROR!!! An error occurred while requesting URL('https://api.refinitiv.com/data/datagrid/beta1/').
#      ReadTimeout('')

# %%
master_df.to_csv('refi_deals_2018.csv')

# %%
master_df[(master_df['TR.MnAAcquirorPriTickerSym'] != "") & (master_df['TR.MnAAcquirorNation'] == "United States")] [['TR.MnAAcquirorPriTickerSym', 'TR.MnAAcquirorUltParentPriTickerSym', 'TR.MnAAnnDate', 'TR.MnAOrigAnnDate', 'TR.MnAAcquirorStockPriceOnAnn', 'TR.MnAAcquirorNation']]
# Out:
#       TR.MnAAcquirorPriTickerSym TR.MnAAcquirorUltParentPriTickerSym  \
# 16                           ARW                                 ARW
# 29                          ASUR                                ASUR
# 30                          ASUR                                ASUR
# 31                          ASUR                                ASUR
# 33                           CMC                                 CMC
# ...                          ...                                 ...
# 58214                        EQR                                 EQR
# 58225                        JNJ                                 JNJ
# 58285                        AJG                                 AJG
# 58319                        ADT                                 APO
# 58378                        JEF                                 JEF
#
#       TR.MnAAnnDate TR.MnAOrigAnnDate  TR.MnAAcquirorStockPriceOnAnn  \
# 16       2018-01-02        2018-01-02                          81.22
# 29       2018-01-02        2018-01-02                          14.96
# 30       2018-01-02        2018-01-02                          14.96
# 31       2018-01-02        2018-01-02                          14.96
# 33       2018-01-02        2017-10-10                          22.77
# ...             ...               ...                            ...
# 58214    2019-01-10        2019-01-10                          67.41
# 58225    2019-01-08        2019-01-08                         129.96
# 58285    2019-01-08        2019-01-08                          72.43
# 58319    2019-01-10        2019-01-10                           6.92
# 58378    2019-01-10        2019-01-10                          22.07
#
#       TR.MnAAcquirorNation
# 16           United States
# 29           United States
# 30           United States
# 31           United States
# 33           United States
# ...                    ...
# 58214        United States
# 58225        United States
# 58285        United States
# 58319        United States
# 58378        United States
#
# [3746 rows x 6 columns]

# %%
rdp.convert_symbols(
    ['APO'], 
    from_symbol_type='TICKER') #TICKER
# rdp.convert_symbols(
#     ['601318'], 
#     from_symbol_type='TICKER')
# Out:
#         IssueISIN TickerSymbol      CUSIP  RIC IssuerOAPermID  \
# APO  US03769M1062          APO  03769M106  APO     5081057199
#
#                                          DocumentTitle
# APO  Apollo Global Management Inc, Ordinary Share, ...

# %%
rdp.get_historical_price_summaries(
    universe = 'APO', 
    interval = rdp.Intervals.DAILY,
    start = "2019-01-10", 
    end = "2019-01-10",
)
# Out:
#             TRDPRC_1  HIGH_1  LOW_1  ACVOL_UNS  OPEN_PRC    BID    ASK  \
# 2019-01-10      26.5   26.82   26.5    1027492     26.82  26.55  26.57
#
#                TRNOVR_UNS     VWAP  BLKCOUNT  BLKVOLUM  NUM_MOVES  TRD_STATUS  \
# 2019-01-10  27369631.7112  26.6373         2     64886       6693         212
#
#             SALTIM NAVALUE
# 2019-01-10   75676    None
